# %% [markdown]
# <a href="https://colab.research.google.com/github/spatank/InteractiveFictionCIS700/blob/master/NLP_for_Text_Adventure_Games_part_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # NLP for Text Adventure Games - part 1
#
# In this notebook, we start trying to improve the coverage of the parser in a text adventure game like Action Castle.  The parser is responsible for interpreting the players' input.  A limitation of classic text adventure games was that parsers were able to handle only a limited number of keywords, and did not support the wide range of different ways that it is possible to say a command.  This is one of the key components that makes natural language challenging for computers to handle.
#
# In part 1, we will introduce you to the WordNet resource.  WordNet is a classic resource for natural language processing.  It was created at Princeton University by Christine Fellbaum and George Miller.  It encodes information about synonyms, antonyms, and is-a relationships between words like _troll_ is-a _monster_.  In NLP, is-a relationships are called hypernyms or hyponyms.

# %% [markdown]
# # WordNet
# [WordNet](https://wordnet.princeton.edu) is a lexical knowledge base that encodes a ton of useful information about how words relate to each other.  NLTK provides a Python API to WordNet.

# %%
#!sudo pip3 install nltk 
import nltk
nltk.download('wordnet')
nltk.download('punkt')
from nltk.corpus import wordnet as wn
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# ## Word Senses
# Words with multiple meanings are called _polysemous_ words.  An example of a polysemous word is the word _bug_ which can mean
# 1. an insect
# 2. a virus or microbe that makes you sick
# 3. an error in your computer program
# 4. a covert listening device
# 5. (verb) to annoy/bother
# 6. (verb) to wiretap
#
# WordNet oraganizes word senses into a structure called _synsets_. Each word can have multiple synsets, and each synset represents a different meaning of the word.

# %%
def get_senses(word):
  """Returns a list of word senses (WordNet synsets) for a word"""
  word_senses = wn.synsets(word)
  return word_senses

def get_definition(word_sense):
  return word_sense.definition()

def get_synonyms(word_sense):
  synonyms = []
  for lemma in word_sense.lemmas():
    synonym = lemma.name().replace('_', ' ')
    synonyms.append(synonym)
  return synonyms

#Here are the word senses for "bug". We can see what their distinct meanings are 
#by getting their definitions or their synonyms from WordNet.
word_senses = get_senses("bug")
for i, word_sense in enumerate(word_senses):
  print("\nSense %d: %s" % (i, word_sense.name()))
  print("Definition: ", get_definition(word_sense))
  print("Synonyms: ", get_synonyms(word_sense))
# Out:
# Sense 0: bug.n.01
# Definition:  general term for any insect or similar creeping or crawling invertebrate
# Synonyms:  ['bug']
#
# Sense 1: bug.n.02
# Definition:  a fault or defect in a computer program, system, or machine
# Synonyms:  ['bug', 'glitch']
#
# Sense 2: bug.n.03
# Definition:  a small hidden microphone; for listening secretly
# Synonyms:  ['bug']
#
# Sense 3: hemipterous_insect.n.01
# Definition:  insects with sucking mouthparts and forewings thickened and leathery at the base; usually show incomplete metamorphosis
# Synonyms:  ['hemipterous insect', 'bug', 'hemipteran', 'hemipteron']
#
# Sense 4: microbe.n.01
# Definition:  a minute life form (especially a disease-causing bacterium); the term is not in technical use
# Synonyms:  ['microbe', 'bug', 'germ']
#
# Sense 5: tease.v.01
# Definition:  annoy persistently
# Synonyms:  ['tease', 'badger', 'pester', 'bug', 'beleaguer']
#
# Sense 6: wiretap.v.01
# Definition:  tap a telephone or telegraph wire to get information
# Synonyms:  ['wiretap', 'tap', 'intercept', 'bug']

# %% [markdown]
# ## Hypernyms / Hyponyms
#
# In addition to representing word senses, WordNet also organizes words hierachically. For example, _red_ is a specific kind of _color_, or _microbe_ is a kind of _organism_.  These are example of _hyponym_ relationships.  If X is-a Y then X is a hyponym of Y, and Y is a hypernym of X. So _red_ is a hyponym of _color_ and _color_ is a hypernym of _red_.
#
# In WordNet, each word sense (synset) has its own distinct hypernyms and hyponyms.

# %%
hyper = lambda s: s.hypernyms()
hypo = lambda s: s.hyponyms()

def get_hypernyms(word_sense, depth=5):
  return list(word_sense.closure(hyper, depth=depth))

def get_hyponyms(word_sense, depth=5):
  return list(word_sense.closure(hypo, depth=depth))

word_senses = get_senses("bug")
for i, word_sense in enumerate(word_senses):
  # The synset names include a word from the set of synonyms, 
  # plus a part of speech (n for noun, v for verb), and 
  # the number of the sense (sense 01 is the most common sense).
  print("\nSense %d: %s (%s)" % (i, word_sense.name(), get_definition(word_sense)))
  print("Hypernyms:")
  hypernyms = word_sense.hypernyms()
  while len(hypernyms) >0:
    print("%s\tis a\t%s" % (word_sense.name(), hypernyms[0].name()))
    word_sense = hypernyms[0]
    hypernyms = word_sense.hypernyms()
# Out:
# Sense 0: bug.n.01 (general term for any insect or similar creeping or crawling invertebrate)
# Hypernyms:
# bug.n.01	is a	insect.n.01
# insect.n.01	is a	arthropod.n.01
# arthropod.n.01	is a	invertebrate.n.01
# invertebrate.n.01	is a	animal.n.01
# animal.n.01	is a	organism.n.01
# organism.n.01	is a	living_thing.n.01
# living_thing.n.01	is a	whole.n.02
# whole.n.02	is a	object.n.01
# object.n.01	is a	physical_entity.n.01
# physical_entity.n.01	is a	entity.n.01
#
# Sense 1: bug.n.02 (a fault or defect in a computer program, system, or machine)
# Hypernyms:
# bug.n.02	is a	defect.n.03
# defect.n.03	is a	imperfection.n.01
# imperfection.n.01	is a	state.n.02
# state.n.02	is a	attribute.n.02
# attribute.n.02	is a	abstraction.n.06
# abstraction.n.06	is a	entity.n.01
#
# Sense 2: bug.n.03 (a small hidden microphone; for listening secretly)
# Hypernyms:
# bug.n.03	is a	microphone.n.01
# microphone.n.01	is a	electro-acoustic_transducer.n.01
# electro-acoustic_transducer.n.01	is a	transducer.n.01
# transducer.n.01	is a	electrical_device.n.01
# electrical_device.n.01	is a	device.n.01
# device.n.01	is a	instrumentality.n.03
# instrumentality.n.03	is a	artifact.n.01
# artifact.n.01	is a	whole.n.02
# whole.n.02	is a	object.n.01
# object.n.01	is a	physical_entity.n.01
# physical_entity.n.01	is a	entity.n.01
#
# Sense 3: hemipterous_insect.n.01 (insects with sucking mouthparts and forewings thickened and leathery at the base; usually show incomplete metamorphosis)
# Hypernyms:
# hemipterous_insect.n.01	is a	insect.n.01
# insect.n.01	is a	arthropod.n.01
# arthropod.n.01	is a	invertebrate.n.01
# invertebrate.n.01	is a	animal.n.01
# animal.n.01	is a	organism.n.01
# organism.n.01	is a	living_thing.n.01
# living_thing.n.01	is a	whole.n.02
# whole.n.02	is a	object.n.01
# object.n.01	is a	physical_entity.n.01
# physical_entity.n.01	is a	entity.n.01
#
# Sense 4: microbe.n.01 (a minute life form (especially a disease-causing bacterium); the term is not in technical use)
# Hypernyms:
# microbe.n.01	is a	microorganism.n.01
# microorganism.n.01	is a	organism.n.01
# organism.n.01	is a	living_thing.n.01
# living_thing.n.01	is a	whole.n.02
# whole.n.02	is a	object.n.01
# object.n.01	is a	physical_entity.n.01
# physical_entity.n.01	is a	entity.n.01
#
# Sense 5: tease.v.01 (annoy persistently)
# Hypernyms:
# tease.v.01	is a	torment.v.02
# torment.v.02	is a	harass.v.01
# harass.v.01	is a	annoy.v.01
# annoy.v.01	is a	displease.v.01
#
# Sense 6: wiretap.v.01 (tap a telephone or telegraph wire to get information)
# Hypernyms:
# wiretap.v.01	is a	listen_in.v.02
# listen_in.v.02	is a	listen.v.01
# listen.v.01	is a	perceive.v.01

# %% [markdown]
# ## Text Adventure Commands
# One of the tricky things about creating a text adventure game is anticipating the many different ways that a player might write a command.
#
# If you program the game to understand a command like _give fish to troll_ and the player types in _feed fish to troll_, then a simple parser will fail to understand the command.
#
# Here we're going to use WordNet to expand out the set of commands that we've programmed into the game, with the goal of being able to recognize more varied input from the player.
#
# Instead of just one _give fish to troll_ command, we'll enumerate thouands of alternatives like
#
# * _serve salmon to monster_
# * _serve up food to monster_
# * _feed sea trout to troll_
# * _supply smoked salmon to mythical creature_

# %%
commands = [
	'wear crown',
	'smell rose',
	'eat fish',
	'light lamp',
	'give fish to troll',
	'propose to the princess',
	'go north',
]

# %% [markdown]
# ## Manually Annotate Senses and Hypernyms/Hyponyms
#
# Below is some code that will help you manually annotate the word sense of each word in your list of commands, and confirm which hypernyms and hyponyms are reasonable substitutes that should be recognized if a player types them instead of our command word.

# %% [markdown]
# Here are some helper functions for you. You can just run this cell instead of reading through the functions in detail if you want.

# %%
def annotate_synsets(sentences):
  """This function queries WordNet for each word in a list of sentences,
     and asks the user to input a number corresponding to the synset."""

  word_senses = {}
  # Cached selections maps from word string to the previous
  # selection for this word (an integer)
  cached_selections = {}

  for i, sent in enumerate(sentences):
    words = word_tokenize(sent.lower())

    for word in words:
      sysnsets = wn.synsets(word)
      if len(sysnsets) != 0:
        selection = select_synset(sent, word, sysnsets, cached_selections)
        if selection != None:
          cached_selections[word] = selection
          if selection < len(sysnsets):
            s = sysnsets[selection]
            word_senses[word] = s.name()
  return word_senses


def select_synset(sent, word, sysnsets, cached_selections):
  """Ask the user to select which sense of the word  
     is being used in this sentence."""
  print(sent)
  print(word.upper())

  prev_selection = -1
  if word in cached_selections:
    prev_selection = cached_selections[word]

  for choice, s in enumerate(sysnsets):
    if choice == prev_selection:
      print("*** ", end = '')
    print("%d) %s - %s" % (choice, s.name(), s.definition()))

  choice += 1
  if choice == prev_selection:
    print("*** ", end = '')
  print("%d None of these." % choice)

  selection = -1
  while selection == -1:
    try:
      user_input = input(">")
      if user_input.strip() == 'x':
        # The user can press 'x' to exit.
        return None
      if user_input.strip() == '' and prev_selection > -1:
        # The user can press retrun to confirm the previous selection.
        return prev_selection
      selection = int(user_input)
    except:
      selection = -1
    if selection < 0 or selection > len(sysnsets):
      print("Please select a number between 0-%d, or type 'x' to exit" % len(sysnsets))
      if prev_selection > -1:
        print("You can also press return to confirm the previous selection (marked by ***).")
    else:
      return selection


def confirm_hyponyms(word, sysnset, do_hypernyms_instead=False):
  """Ask the user to confirm which of the hyponyms are applicable 
     for this sentence."""
  print(word.upper())

  confirmed = []
  if do_hypernyms_instead:
    unconfirmed = sysnset.hypernyms()
  else:
    unconfirmed = sysnset.hyponyms()

  while len(unconfirmed) > 0:
    s = unconfirmed.pop(0)
    print("Is %s an appropriate substitute for %s? (y/n)" % (s.name(), word))
    print("It means:", s.definition())
    print("Synonyms are:", get_synonyms(s))
    user_input = ''
    while user_input == '':
      user_input = input(">")
      user_input = user_input.strip()
      if user_input == 'y' or user_input == 'yes':
        confirmed.append(s.name())
        if do_hypernyms_instead:
          unconfirmed.extend(s.hypernyms())
        else:
          unconfirmed.extend(s.hyponyms())
        
      elif user_input == 'n' or user_input == 'no':
        pass
      elif user_input == 'x':
        # The user can press 'x' to exit.
        return confirmed
      else:
        print("Please type 'yes' or 'no' or 'x' to stop confirming for this word")
        user_input = ''
  return confirmed

# Save your annotations to a file, so that you can submit them with your homework.
def save_to_drive(word_senses, confirmed_hyponyms, confirmed_hypernyms):
  import json
  from google.colab import drive
  drive.mount('/content/drive/')

  output_file = '/content/drive/My Drive/word-sense-annotations.json'
  output_json = {}
  output_json['senses'] = word_senses
  output_json['hyponyms'] = confirmed_hyponyms
  output_json['hypernyms'] = confirmed_hypernyms

  with open(output_file, 'w') as write_file:
    write_file.write(json.dumps(output_json, sort_keys=True, indent=4))
    write_file.write('\n')

# %% [markdown]
# Run this part when you're ready to start annotating the words in the commands. I estimate that it will take about 10 minutes per command.  Your annotations will be saved to a file in your Google Drive called _word-sense-annotations.json_, so that you can submit them with your homework.  You'll be prompted to enter a code to authorize Colab to write to your Google Drive. Be sure to do this so that your work will be saved.

# %%
word_senses = annotate_synsets(commands)
confirmed_hyponyms = {}
confirmed_hypernyms = {}
for word in word_senses:
  print("First, pick the word sense for the word '%s'" % word)
  print("==============")
  word_sense = wn.synset(word_senses[word])
  print("\nNext, pick which hypernyms of %s we should allow players to use." % word_sense.name())
  print("==============")
  confirmed_hypernyms[word] = confirm_hyponyms(word, word_sense, do_hypernyms_instead=True)
  print("\Finally, pick which hyponyms of %s we should allow players to use." % word_sense.name())
  print("==============")  
  confirmed_hyponyms[word] = confirm_hyponyms(word, word_sense)


print("You're done annotating!  Save your annotation to your Google drive.")
print("You need to paste in a confirmation code to allow Colab to have access.")
print("We'll create a file called 'word-sense-annotations.json' for you to turn in.")
print("==============")
save_to_drive(word_senses, confirmed_hyponyms, confirmed_hypernyms)
# Out:
# wear crown
# WEAR
# 0) wear.n.01 - impairment resulting from long use
# 1) clothing.n.01 - a covering designed to be worn on a person's body
# 2) wear.n.03 - the act of having on your person as a covering or adornment
# 3) wear.v.01 - be dressed in
# 4) wear.v.02 - have on one's person
# 5) wear.v.03 - have in one's aspect; wear an expression of one's attitude or personality
# 6) wear.v.04 - deteriorate through use or stress
# 7) wear.v.05 - have or show an appearance of
# 8) wear.v.06 - last and be usable
# 9) break.v.42 - go to pieces
# 10) tire.v.02 - exhaust or get tired through overuse or great strain or stress
# 11) wear.v.09 - put clothing on one's body
# 12 None of these.
# >2
# wear crown
# CROWN
# 0) crown.n.01 - the Crown (or the reigning monarch) as the symbol of the power and authority of a monarchy
# 1) crown.n.02 - the part of a tooth above the gum that is covered with enamel
# 2) crown.n.03 - a wreath or garland worn on the head to signify victory
# 3) crown.n.04 - an ornamental jeweled headdress signifying sovereignty
# 4) crown.n.05 - the part of a hat (the vertex) that covers the crown of the head
# 5) crown.n.06 - an English coin worth 5 shillings
# 6) crown.n.07 - the upper branches and leaves of a tree or other plant
# 7) peak.n.04 - the top or extreme point of something (usually a mountain or hill)
# 8) pennant.n.01 - the award given to the champion
# 9) pate.n.02 - the top of the head
# 10) crown.n.11 - (dentistry) dental appliance consisting of an artificial crown for a broken or decayed tooth
# 11) crown.n.12 - the center of a cambered road
# 12) crown.v.01 - invest with regal power; enthrone
# 13) crown.v.02 - be the culminating event
# 14) crown.v.03 - form the topmost part of
# 15) crown.v.04 - put an enamel cover on
# 16 None of these.
# >1
# smell rose
# SMELL
# 0) smell.n.01 - the sensation that results when olfactory receptors in the nose are stimulated by particular chemicals in gaseous form
# 1) olfactory_property.n.01 - any property detected by the olfactory system
# 2) spirit.n.02 - the general atmosphere of a place or situation and the effect that it has on people
# 3) smell.n.04 - the faculty that enables us to distinguish scents
# 4) smell.n.05 - the act of perceiving the odor of something
# 5) smell.v.01 - inhale the odor of; perceive by the olfactory sense
# 6) smell.v.02 - emit an odor
# 7) smell.v.03 - smell bad
# 8) smack.v.02 - have an element suggestive (of something)
# 9) smell.v.05 - become aware of not through the senses but instinctively
# 10 None of these.
# >5
# smell rose
# ROSE
# 0) rose.n.01 - any of many shrubs of the genus Rosa that bear roses
# 1) blush_wine.n.01 - pinkish table wine from red grapes whose skins were removed after fermentation began
# 2) rose.n.03 - a dusty pink color
# 3) rise.v.01 - move upward
# 4) rise.v.02 - increase in value or to a higher point
# 5) arise.v.03 - rise to one's feet
# 6) rise.v.04 - rise up
# 7) surface.v.01 - come to the surface
# 8) originate.v.01 - come into existence; take on form or shape
# 9) ascend.v.08 - move to a better position in life or to a better job
# 10) wax.v.02 - go up or advance
# 11) heighten.v.01 - become more extreme
# 12) get_up.v.02 - get up and out of bed
# 13) rise.v.11 - rise in rank or status
# 14) rise.v.12 - become heartened or elated
# 15) rise.v.13 - exert oneself to meet a challenge
# 16) rebel.v.01 - take part in a rebellion; renounce a former allegiance
# 17) rise.v.15 - increase in volume
# 18) rise.v.16 - come up, of celestial bodies
# 19) resurrect.v.03 - return from the dead
# 20) rose.s.01 - of something having a dusty purplish pink color
# 21 None of these.
# >0
# eat fish
# EAT
# 0) eat.v.01 - take in solid food
# 1) eat.v.02 - eat a meal; take a meal
# 2) feed.v.06 - take in food; used of animals only
# 3) eat.v.04 - worry or cause anxiety in a persistent way
# 4) consume.v.05 - use up (resources or materials)
# 5) corrode.v.01 - cause to deteriorate due to the action of water, air, or an acid
# 6 None of these.
# >0
# eat fish
# FISH
# 0) fish.n.01 - any of various mostly cold-blooded aquatic vertebrates usually having scales and breathing through gills
# 1) fish.n.02 - the flesh of fish used as food
# 2) pisces.n.02 - (astrology) a person who is born while the sun is in Pisces
# 3) pisces.n.01 - the twelfth sign of the zodiac; the sun is in this sign from about February 19 to March 20
# 4) fish.v.01 - seek indirectly
# 5) fish.v.02 - catch or try to catch fish or shellfish
# 6 None of these.
# >0
# light lamp
# LIGHT
# 0) light.n.01 - (physics) electromagnetic radiation that can produce a visual sensation
# 1) light.n.02 - any device serving as a source of illumination
# 2) light.n.03 - a particular perspective or aspect of a situation
# 3) luminosity.n.01 - the quality of being luminous; emitting or reflecting light
# 4) light.n.05 - an illuminated area
# 5) light.n.06 - a condition of spiritual awareness; divine illumination
# 6) light.n.07 - the visual effect of illumination on objects or scenes as created in pictures
# 7) light.n.08 - a person regarded very fondly
# 8) light.n.09 - having abundant light or illumination
# 9) light.n.10 - mental understanding as an enlightening experience
# 10) sparkle.n.01 - merriment expressed by a brightness or gleam or animation of countenance
# 11) light.n.12 - public awareness
# 12) inner_light.n.01 - a divine presence believed by Quakers to enlighten and guide the soul
# 13) light.n.14 - a visual warning signal
# 14) lighter.n.02 - a device for lighting or igniting fuel or charges or fires
# 15) light.v.01 - make lighter or brighter
# 16) light_up.v.05 - begin to smoke
# 17) alight.v.01 - to come to rest, settle
# 18) ignite.v.01 - cause to start burning; subject to fire or great heat
# 19) fall.v.20 - fall to somebody by assignment or lot
# 20) unhorse.v.01 - alight from (a horse)
# 21) light.a.01 - of comparatively little physical weight or density
# 22) light.a.02 - (used of color) having a relatively small amount of coloring agent
# 23) light.a.03 - of the military or industry; using (or being) relatively small or light arms or equipment
# 24) light.a.04 - not great in degree or quantity or number
# 25) light.a.05 - psychologically light; especially free from sadness or troubles
# 26) light.a.06 - characterized by or emitting light
# 27) unaccented.s.02 - (used of vowels or syllables) pronounced with little or no stress
# 28) light.s.08 - easily assimilated in the alimentary canal; not rich or heavily seasoned
# 29) light.s.09 - (used of soil) loose and large-grained in consistency
# 30) clean.s.03 - (of sound or color) free from anything that dulls or dims
# 31) light.s.11 - moving easily and quickly; nimble
# 32) light.s.12 - demanding little effort; not burdensome
# 33) light.a.13 - of little intensity or power or force
# 34) light.a.14 - (physics, chemistry) not having atomic weight greater than average
# 35) faint.s.04 - weak and likely to lose consciousness
# 36) light.s.16 - very thin and insubstantial
# 37) abstemious.s.02 - marked by temperance in indulgence
# 38) light.s.18 - less than the correct or legal or full amount often deliberately so
# 39) light.s.19 - having little importance
# 40) light.s.20 - intended primarily as entertainment; not serious or profound
# 41) idle.s.04 - silly or trivial
# 42) light.s.22 - designed for ease of movement or to carry little weight
# 43) light.s.23 - having relatively few calories
# 44) light.s.24 - (of sleep) easily disturbed
# 45) easy.s.10 - casual and unrestrained in sexual behavior
# 46) lightly.r.02 - with few burdens
# 47 None of these.
# >18
# light lamp
# LAMP
# 0) lamp.n.01 - an artificial source of visible illumination
# 1) lamp.n.02 - a piece of furniture holding one or more electric light bulbs
# 2 None of these.
# >0
# give fish to troll
# GIVE
# 0) give.n.01 - the elasticity of something that can be stretched and returns to its original length
# 1) give.v.01 - cause to have, in the abstract sense or physical sense
# 2) yield.v.01 - be the cause or source of
# 3) give.v.03 - transfer possession of something concrete or abstract to somebody
# 4) give.v.04 - convey or reveal information
# 5) give.v.05 - convey, as of a compliment, regards, attention, etc.; bestow
# 6) hold.v.03 - organize or be responsible for
# 7) give.v.07 - convey or communicate; of a smile, a look, a physical gesture
# 8) give.v.08 - give as a present; make a gift of
# 9) give.v.09 - cause to happen or be responsible for
# 10) give.v.10 - dedicate
# 11) render.v.04 - give or supply
# 12) impart.v.01 - transmit (knowledge or skills)
# 13) establish.v.05 - bring about
# 14) give.v.14 - leave with; give temporarily
# 15) give.v.15 - emit or utter
# 16) sacrifice.v.01 - endure the loss of
# 17) pass.v.05 - place into the hands or custody of
# 18) give.v.18 - give entirely to a specific person, activity, or cause
# 19) give.v.19 - give (as medicine)
# 20) give.v.20 - give or convey physically
# 21) give.v.21 - bestow
# 22) grant.v.05 - bestow, especially officially
# 23) move_over.v.01 - move in order to make room for someone for something
# 24) feed.v.02 - give food to
# 25) contribute.v.02 - contribute to some cause
# 26) collapse.v.01 - break down, literally or metaphorically
# 27) give.v.27 - estimate the duration or outcome of something
# 28) give.v.28 - execute and deliver
# 29) give.v.29 - deliver in exchange or recompense
# 30) afford.v.04 - afford access to
# 31) give.v.31 - present to view
# 32) give.v.32 - perform for an audience
# 33) give.v.33 - be flexible under stress of physical force
# 34) give.v.34 - propose
# 35) give.v.35 - accord by verdict
# 36) give.v.36 - manifest or show
# 37) give.v.37 - offer in good faith
# 38) give.v.38 - submit for consideration, judgment, or use
# 39) give.v.39 - guide or direct, as by behavior of persuasion
# 40) give.v.40 - allow to have or take
# 41) give.v.41 - inflict as a punishment
# 42) give.v.42 - occur
# 43) give.v.43 - consent to engage in sexual intercourse with a man
# 44) give.v.44 - proffer (a body part)
# 45 None of these.
# >3
# give fish to troll
# FISH
# *** 0) fish.n.01 - any of various mostly cold-blooded aquatic vertebrates usually having scales and breathing through gills
# 1) fish.n.02 - the flesh of fish used as food
# 2) pisces.n.02 - (astrology) a person who is born while the sun is in Pisces
# 3) pisces.n.01 - the twelfth sign of the zodiac; the sun is in this sign from about February 19 to March 20
# 4) fish.v.01 - seek indirectly
# 5) fish.v.02 - catch or try to catch fish or shellfish
# 6 None of these.
# >0
# give fish to troll
# TROLL
# 0) troll.n.01 - (Scandanavian folklore) a supernatural creature (either a dwarf or a giant) that is supposed to live in caves or in the mountains
# 1) round.n.11 - a partsong in which voices follow each other; one voice starts and others join in one after another until all are singing different parts of the song at the same time
# 2) troll.n.03 - a fisherman's lure that is used in trolling
# 3) troll.n.04 - angling by drawing a baited line through the water
# 4) troll.v.01 - circulate, move around
# 5) troll.v.02 - cause to move round and round
# 6) troll.v.03 - sing the parts of (a round) in succession
# 7) troll.v.04 - angle with a hook and line drawn through the water
# 8) troll.v.05 - sing loudly and without inhibition
# 9) troll.v.06 - praise or celebrate in song
# 10) troll.v.07 - speak or recite rapidly or in a rolling voice
# 11 None of these.
# >0
# propose to the princess
# PROPOSE
# 0) propose.v.01 - make a proposal, declare a plan for something
# 1) project.v.08 - present for consideration, examination, criticism, etc.
# 2) aim.v.02 - propose or intend
# 3) nominate.v.02 - put forward; nominate for appointment to an office or for an honor or position
# 4) propose.v.05 - ask (someone) to marry you
# 5 None of these.
# >4
# propose to the princess
# PRINCESS
# 0) princess.n.01 - a female member of a royal family other than the queen (especially the daughter of a sovereign)
# 1 None of these.
# >0
# go north
# GO
# 0) go.n.01 - a time for working (after which you will be relieved by someone else)
# 1) adam.n.03 - street names for methylenedioxymethamphetamine
# 2) crack.n.09 - a usually brief attempt
# 3) go.n.04 - a board game for two players who place counters on a grid; the object is to surround and so capture the opponent's counters
# 4) travel.v.01 - change location; move, travel, or proceed, also metaphorically
# 5) go.v.02 - follow a procedure or take a course
# 6) go.v.03 - move away from a place into another direction
# 7) become.v.01 - enter or assume a certain state or condition
# 8) go.v.05 - be awarded; be allotted
# 9) run.v.05 - have a particular form
# 10) run.v.03 - stretch out over a distance, space, time, or scope; run or extend between two points or beyond a certain point
# 11) proceed.v.04 - follow a certain course
# 12) go.v.09 - be abolished or discarded
# 13) go.v.10 - be or continue to be in a certain condition
# 14) sound.v.02 - make a certain noise or sound
# 15) function.v.01 - perform as expected when applied
# 16) run_low.v.01 - to be spent or finished
# 17) move.v.13 - progress by being changed
# 18) survive.v.01 - continue to live through hardship or adversity
# 19) go.v.16 - pass, fare, or elapse; of a certain state of affairs or action
# 20) die.v.01 - pass from physical life and lose all bodily attributes and functions necessary to sustain life
# 21) belong.v.03 - be in the right place or situation
# 22) go.v.19 - be ranked or compare
# 23) start.v.09 - begin or set in motion
# 24) move.v.15 - have a turn; make one's move in a game
# 25) go.v.22 - be contained in
# 26) go.v.23 - be sounded, played, or expressed
# 27) blend.v.02 - blend or harmonize
# 28) go.v.25 - lead, extend, or afford access
# 29) fit.v.02 - be the right size or shape; fit correctly or as desired
# 30) rifle.v.02 - go through in search of something; search through someone's belongings in an unauthorized way
# 31) go.v.28 - be spent
# 32) plump.v.04 - give support (to) or make a choice (of) one out of a group or number
# 33) fail.v.04 - stop operating or functioning
# 34) go.a.01 - functioning correctly and ready for action
# 35 None of these.
# >6
# go north
# NORTH
# 0) north.n.01 - the region of the United States lying to the north of the Mason-Dixon line
# 1) union.n.02 - the United States (especially the northern states during the American Civil War)
# 2) north.n.03 - the cardinal compass point that is at 0 or 360 degrees
# 3) north.n.04 - a location in the northern part of a country, region, or city
# 4) north.n.05 - the direction corresponding to the northward cardinal compass point
# 5) north.n.06 - the direction in which a compass needle points
# 6) north.n.07 - British statesman under George III whose policies led to rebellion in the American colonies (1732-1792)
# 7) north.a.01 - situated in or facing or moving toward or coming from the north
# 8) north.r.01 - in a northern direction
# 9 None of these.
# >8
# First, pick the word sense for the word 'wear'
# ==============
#
# Next, pick which hypernyms of wear.n.03 we should allow players to use.
# ==============
# WEAR
# Is act.n.02 an appropriate substitute for wear? (y/n)
# It means: something that people do or cause to happen
# Synonyms are: ['act', 'deed', 'human action', 'human activity']
# >n
# \Finally, pick which hyponyms of wear.n.03 we should allow players to use.
# ==============
# WEAR
# First, pick the word sense for the word 'crown'
# ==============
#
# Next, pick which hypernyms of crown.n.02 we should allow players to use.
# ==============
# CROWN
# Is top.n.01 an appropriate substitute for crown? (y/n)
# It means: the upper part of anything
# Synonyms are: ['top']
# >n
# \Finally, pick which hyponyms of crown.n.02 we should allow players to use.
# ==============
# CROWN
# First, pick the word sense for the word 'smell'
# ==============
#
# Next, pick which hypernyms of smell.v.01 we should allow players to use.
# ==============
# SMELL
# Is perceive.v.01 an appropriate substitute for smell? (y/n)
# It means: to become aware of through the senses
# Synonyms are: ['perceive', 'comprehend']
# >y
# \Finally, pick which hyponyms of smell.v.01 we should allow players to use.
# ==============
# SMELL
# Is get_a_noseful.v.01 an appropriate substitute for smell? (y/n)
# It means: smell strongly and intensely
# Synonyms are: ['get a noseful', 'get a whiff']
# >y
# Is scent.v.02 an appropriate substitute for smell? (y/n)
# It means: catch the scent of; get wind of
# Synonyms are: ['scent', 'nose', 'wind']
# >y
# Is sniff.v.01 an appropriate substitute for smell? (y/n)
# It means: perceive by inhaling through the nose
# Synonyms are: ['sniff', 'whiff']
# >y
# Is snuff.v.01 an appropriate substitute for smell? (y/n)
# It means: sniff or smell inquiringly
# Synonyms are: ['snuff', 'snuffle']
# >y
# First, pick the word sense for the word 'rose'
# ==============
#
# Next, pick which hypernyms of rose.n.01 we should allow players to use.
# ==============
# ROSE
# Is shrub.n.01 an appropriate substitute for rose? (y/n)
# It means: a low woody perennial plant usually having several major stems
# Synonyms are: ['shrub', 'bush']
# >n
# \Finally, pick which hyponyms of rose.n.01 we should allow players to use.
# ==============
# ROSE
# Is banksia_rose.n.01 an appropriate substitute for rose? (y/n)
# It means: Chinese evergreen climbing rose with yellow or white single flowers
# Synonyms are: ['banksia rose', 'Rosa banksia']
# >n
# Is cherokee_rose.n.01 an appropriate substitute for rose? (y/n)
# It means: Chinese climbing rose with fragrant white blossoms
# Synonyms are: ['Cherokee rose', 'Rosa laevigata']
# >n
# Is china_rose.n.01 an appropriate substitute for rose? (y/n)
# It means: shrubby Chinese rose; ancestor of many cultivated garden roses
# Synonyms are: ['China rose', 'Bengal rose', 'Rosa chinensis']
# >y
# Is damask_rose.n.01 an appropriate substitute for rose? (y/n)
# It means: large hardy very fragrant pink rose; cultivated in Asia Minor as source of attar of roses; parent of many hybrids
# Synonyms are: ['damask rose', 'summer damask rose', 'Rosa damascena']
# >y
# Is dog_rose.n.01 an appropriate substitute for rose? (y/n)
# It means: prickly wild rose with delicate pink or white scentless flowers; native to Europe
# Synonyms are: ['dog rose', 'Rosa canina']
# >y
# Is ground_rose.n.01 an appropriate substitute for rose? (y/n)
# It means: low-growing bristly shrub of southern Oregon and California with creeping rootstocks and usually corymbose flowers
# Synonyms are: ['ground rose', 'Rosa spithamaea']
# >n
# Is mountain_rose.n.01 an appropriate substitute for rose? (y/n)
# It means: European alpine rose with crimson flowers
# Synonyms are: ['mountain rose', 'Rosa pendulina']
# >y
# Is multiflora.n.01 an appropriate substitute for rose? (y/n)
# It means: vigorously growing rose having clusters of numerous small flowers; used for hedges and as grafting stock
# Synonyms are: ['multiflora', 'multiflora rose', 'Japanese rose', 'baby rose', 'Rosa multiflora']
# >y
# Is musk_rose.n.01 an appropriate substitute for rose? (y/n)
# It means: rose native to Mediterranean region having curved or climbing branches and loose clusters of musky-scented flowers
# Synonyms are: ['musk rose', 'Rosa moschata']
# >y
# Is sweetbrier.n.01 an appropriate substitute for rose? (y/n)
# It means: Eurasian rose with prickly stems and fragrant leaves and bright pink flowers followed by scarlet hips
# Synonyms are: ['sweetbrier', 'sweetbriar', 'brier', 'briar', 'eglantine', 'Rosa eglanteria']
# >y
# Is tea_rose.n.01 an appropriate substitute for rose? (y/n)
# It means: any of several hybrid bush roses derived from a tea-scented Chinese rose with pink or yellow flowers
# Synonyms are: ['tea rose', 'Rosa odorata']
# >n
# First, pick the word sense for the word 'eat'
# ==============
#
# Next, pick which hypernyms of eat.v.01 we should allow players to use.
# ==============
# EAT
# Is consume.v.02 an appropriate substitute for eat? (y/n)
# It means: serve oneself to, or consume regularly
# Synonyms are: ['consume', 'ingest', 'take in', 'take', 'have']
# >y
# Is eat.v.02 an appropriate substitute for eat? (y/n)
# It means: eat a meal; take a meal
# Synonyms are: ['eat']
# >y
# Is consume.v.02 an appropriate substitute for eat? (y/n)
# It means: serve oneself to, or consume regularly
# Synonyms are: ['consume', 'ingest', 'take in', 'take', 'have']
# >y
# \Finally, pick which hyponyms of eat.v.01 we should allow players to use.
# ==============
# EAT
# Is devour.v.03 an appropriate substitute for eat? (y/n)
# It means: eat immoderately
# Synonyms are: ['devour', 'down', 'consume', 'go through']
# >y
# Is devour.v.04 an appropriate substitute for eat? (y/n)
# It means: eat greedily
# Synonyms are: ['devour', 'guttle', 'raven', 'pig']
# >y
# Is dunk.v.03 an appropriate substitute for eat? (y/n)
# It means: dip into a liquid while eating
# Synonyms are: ['dunk', 'dip']
# >n
# Is eat_up.v.01 an appropriate substitute for eat? (y/n)
# It means: finish eating all the food on one's plate or on the table
# Synonyms are: ['eat up', 'finish', 'polish off']
# >y
# Is fare.v.02 an appropriate substitute for eat? (y/n)
# It means: eat well
# Synonyms are: ['fare']
# >y
# Is fill_up.v.04 an appropriate substitute for eat? (y/n)
# It means: eat until one is sated
# Synonyms are: ['fill up', 'fill']
# >y
# Is garbage_down.v.01 an appropriate substitute for eat? (y/n)
# It means: eat a large amount of food quickly
# Synonyms are: ['garbage down', 'gobble up', 'shovel in', 'bolt down']
# >n
# Is gluttonize.v.01 an appropriate substitute for eat? (y/n)
# It means: eat a lot and without restraint
# Synonyms are: ['gluttonize', 'gluttonise', 'fress']
# >y
# Is gobble.v.01 an appropriate substitute for eat? (y/n)
# It means: eat hastily without proper chewing
# Synonyms are: ['gobble', 'bolt']
# >y
# Is nibble.v.03 an appropriate substitute for eat? (y/n)
# It means: eat intermittently; take small bites of
# Synonyms are: ['nibble', 'pick', 'piece']
# >y
# Is peck.v.02 an appropriate substitute for eat? (y/n)
# It means: eat by pecking at, like a bird
# Synonyms are: ['peck', 'pick up']
# >n
# Is pick_at.v.02 an appropriate substitute for eat? (y/n)
# It means: eat like a bird
# Synonyms are: ['pick at', 'peck at', 'peck']
# >n
# Is pitch_in.v.01 an appropriate substitute for eat? (y/n)
# It means: eat heartily
# Synonyms are: ['pitch in', 'dig in']
# >y
# Is ruminate.v.01 an appropriate substitute for eat? (y/n)
# It means: chew the cuds
# Synonyms are: ['ruminate']
# >n
# Is slurp.v.01 an appropriate substitute for eat? (y/n)
# It means: eat noisily
# Synonyms are: ['slurp']
# >y
# Is wash_down.v.01 an appropriate substitute for eat? (y/n)
# It means: eat food accompanied by lots of liquid; also use metaphorically
# Synonyms are: ['wash down']
# >n
# Is wolf.v.01 an appropriate substitute for eat? (y/n)
# It means: eat hastily
# Synonyms are: ['wolf', 'wolf down']
# >y
# Is tuck_in.v.01 an appropriate substitute for eat? (y/n)
# It means: eat up; usually refers to a considerable quantity of food
# Synonyms are: ['tuck in', 'tuck away', 'put away']
# >n
# First, pick the word sense for the word 'fish'
# ==============
#
# Next, pick which hypernyms of fish.n.01 we should allow players to use.
# ==============
# FISH
# Is aquatic_vertebrate.n.01 an appropriate substitute for fish? (y/n)
# It means: animal living wholly or chiefly in or on water
# Synonyms are: ['aquatic vertebrate']
# >y
# Is vertebrate.n.01 an appropriate substitute for fish? (y/n)
# It means: animals having a bony or cartilaginous skeleton with a segmented spinal column and a large brain enclosed in a skull or cranium
# Synonyms are: ['vertebrate', 'craniate']
# >y
# Is chordate.n.01 an appropriate substitute for fish? (y/n)
# It means: any animal of the phylum Chordata having a notochord or spinal column
# Synonyms are: ['chordate']
# >y
# Is animal.n.01 an appropriate substitute for fish? (y/n)
# It means: a living organism characterized by voluntary movement
# Synonyms are: ['animal', 'animate being', 'beast', 'brute', 'creature', 'fauna']
# >y
# Is organism.n.01 an appropriate substitute for fish? (y/n)
# It means: a living thing that has (or can develop) the ability to act or function independently
# Synonyms are: ['organism', 'being']
# >y
# Is living_thing.n.01 an appropriate substitute for fish? (y/n)
# It means: a living (or once living) entity
# Synonyms are: ['living thing', 'animate thing']
# >y
# Is whole.n.02 an appropriate substitute for fish? (y/n)
# It means: an assemblage of parts that is regarded as a single entity
# Synonyms are: ['whole', 'unit']
# >n
# \Finally, pick which hyponyms of fish.n.01 we should allow players to use.
# ==============
# FISH
# Is bony_fish.n.01 an appropriate substitute for fish? (y/n)
# It means: any fish of the class Osteichthyes
# Synonyms are: ['bony fish']
# >y
# Is bottom-feeder.n.02 an appropriate substitute for fish? (y/n)
# It means: a fish that lives and feeds on the bottom of a body of water
# Synonyms are: ['bottom-feeder', 'bottom-dweller']
# >n
# Is bottom_lurkers.n.01 an appropriate substitute for fish? (y/n)
# It means: a fish that lurks on the bottom of a body of water
# Synonyms are: ['bottom lurkers']
# >n
# Is cartilaginous_fish.n.01 an appropriate substitute for fish? (y/n)
# It means: fishes in which the skeleton may be calcified but not ossified
# Synonyms are: ['cartilaginous fish', 'chondrichthian']
# >n
# Is climbing_perch.n.01 an appropriate substitute for fish? (y/n)
# It means: a small perch of India whose gills are modified to allow it to breathe air; has spiny pectoral fins that enable it to travel on land
# Synonyms are: ['climbing perch', 'Anabas testudineus', 'A. testudineus']
# >n
# Is fingerling.n.01 an appropriate substitute for fish? (y/n)
# It means: a young or small fish
# Synonyms are: ['fingerling']
# >n
# Is food_fish.n.01 an appropriate substitute for fish? (y/n)
# It means: any fish used for food by human beings
# Synonyms are: ['food fish']
# >y
# Is game_fish.n.01 an appropriate substitute for fish? (y/n)
# It means: any fish providing sport for the angler
# Synonyms are: ['game fish', 'sport fish']
# >y
# Is mouthbreeder.n.01 an appropriate substitute for fish? (y/n)
# It means: any of various fishes that carry their eggs and their young in their mouths
# Synonyms are: ['mouthbreeder']
# >n
# Is northern_snakehead.n.01 an appropriate substitute for fish? (y/n)
# It means: a voracious freshwater fish that is native to northeastern China; can use fin to walk and can survive out of water for three days; a threat to American populations of fish
# Synonyms are: ['northern snakehead']
# >n
# Is rough_fish.n.01 an appropriate substitute for fish? (y/n)
# It means: any fish useless for food or sport or even as bait
# Synonyms are: ['rough fish']
# >n
# Is spawner.n.01 an appropriate substitute for fish? (y/n)
# It means: a female fish at spawning time
# Synonyms are: ['spawner']
# >n
# Is young_fish.n.01 an appropriate substitute for fish? (y/n)
# It means: a fish that is young
# Synonyms are: ['young fish']
# >y
# Is crossopterygian.n.01 an appropriate substitute for fish? (y/n)
# It means: any fish of the order Crossopterygii; most known only in fossil form
# Synonyms are: ['crossopterygian', 'lobefin', 'lobe-finned fish']
# >n
# Is lungfish.n.01 an appropriate substitute for fish? (y/n)
# It means: air-breathing fish having an elongated body and fleshy paired fins; certain species construct mucus-lined mud coverings in which to survive drought
# Synonyms are: ['lungfish']
# >n
# Is teleost_fish.n.01 an appropriate substitute for fish? (y/n)
# It means: a bony fish of the subclass Teleostei
# Synonyms are: ['teleost fish', 'teleost', 'teleostan']
# >n
# Is barracouta.n.01 an appropriate substitute for fish? (y/n)
# It means: a large marine food fish common on the coasts of Australia, New Zealand, and southern Africa
# Synonyms are: ['barracouta', 'snoek']
# >n
# Is groundfish.n.01 an appropriate substitute for fish? (y/n)
# It means: fish that live on the sea bottom (particularly the commercially important gadoid fish like cod and haddock, or flatfish like flounder)
# Synonyms are: ['groundfish', 'bottom fish']
# >n
# Is herring.n.02 an appropriate substitute for fish? (y/n)
# It means: commercially important food fish of northern waters of both Atlantic and Pacific
# Synonyms are: ['herring', 'Clupea harangus']
# >y
# Is salmon.n.01 an appropriate substitute for fish? (y/n)
# It means: any of various large food and game fishes of northern waters; usually migrate from salt to fresh water to spawn
# Synonyms are: ['salmon']
# >y
# Is sardine.n.02 an appropriate substitute for fish? (y/n)
# It means: any of various small edible herring or related food fishes frequently canned
# Synonyms are: ['sardine']
# >y
# Is sea_bass.n.02 an appropriate substitute for fish? (y/n)
# It means: any of various food and sport fishes of the Atlantic coast of the United States having an elongated body and long spiny dorsal fin
# Synonyms are: ['sea bass']
# >y
# Is shad.n.02 an appropriate substitute for fish? (y/n)
# It means: herring-like food fishes that migrate from the sea to fresh water to spawn
# Synonyms are: ['shad']
# >y
# Is snapper.n.05 an appropriate substitute for fish? (y/n)
# It means: any of several large sharp-toothed marine food and sport fishes of the family Lutjanidae of mainly tropical coastal waters
# Synonyms are: ['snapper']
# >n
# Is sole.n.04 an appropriate substitute for fish? (y/n)
# It means: right-eyed flatfish; many are valued as food; most common in warm seas especially European
# Synonyms are: ['sole']
# >n
# Is trout.n.02 an appropriate substitute for fish? (y/n)
# It means: any of various game and food fishes of cool fresh waters mostly smaller than typical salmons
# Synonyms are: ['trout']
# >y
# Is tuna.n.03 an appropriate substitute for fish? (y/n)
# It means: any very large marine food and game fish of the genus Thunnus; related to mackerel; chiefly of warm waters
# Synonyms are: ['tuna', 'tunny']
# >n
# Is whitefish.n.03 an appropriate substitute for fish? (y/n)
# It means: silvery herring-like freshwater food fish of cold lakes of the northern hemisphere
# Synonyms are: ['whitefish']
# >y
# Is brit.n.02 an appropriate substitute for fish? (y/n)
# It means: the young of a herring or sprat or similar fish
# Synonyms are: ['brit', 'britt']
# >n
# Is parr.n.02 an appropriate substitute for fish? (y/n)
# It means: a young salmon up to 2 years old
# Synonyms are: ['parr']
# >n
# Is parr.n.03 an appropriate substitute for fish? (y/n)
# It means: the young of various fishes
# Synonyms are: ['parr']
# >y
# Is whitebait.n.02 an appropriate substitute for fish? (y/n)
# It means: the edible young of especially herrings and sprats and smelts
# Synonyms are: ['whitebait']
# >y
# Is atlantic_herring.n.01 an appropriate substitute for fish? (y/n)
# It means: important food fish; found in enormous shoals in the northern Atlantic
# Synonyms are: ['Atlantic herring', 'Clupea harengus harengus']
# >n
# Is pacific_herring.n.01 an appropriate substitute for fish? (y/n)
# It means: important food fish of the northern Pacific
# Synonyms are: ['Pacific herring', 'Clupea harengus pallasii']
# >n
# Is atlantic_salmon.n.02 an appropriate substitute for fish? (y/n)
# It means: found in northern coastal Atlantic waters or tributaries; adults do not die after spawning
# Synonyms are: ['Atlantic salmon', 'Salmo salar']
# >n
# Is blackfish.n.02 an appropriate substitute for fish? (y/n)
# It means: female salmon that has recently spawned
# Synonyms are: ['blackfish']
# >n
# Is chinook.n.05 an appropriate substitute for fish? (y/n)
# It means: large Pacific salmon valued as food; adults die after spawning
# Synonyms are: ['chinook', 'chinook salmon', 'king salmon', 'quinnat salmon', 'Oncorhynchus tshawytscha']
# >n
# Is chum_salmon.n.01 an appropriate substitute for fish? (y/n)
# It means: a large Pacific salmon with small spots on its back; an important food fish
# Synonyms are: ['chum salmon', 'chum', 'Oncorhynchus keta']
# >n
# Is coho.n.02 an appropriate substitute for fish? (y/n)
# It means: small salmon of northern Pacific coasts and the Great Lakes
# Synonyms are: ['coho', 'cohoe', 'coho salmon', 'blue jack', 'silver salmon', 'Oncorhynchus kisutch']
# >n
# Is redfish.n.03 an appropriate substitute for fish? (y/n)
# It means: male salmon that has recently spawned
# Synonyms are: ['redfish']
# >
# Please type 'yes' or 'no' or 'x' to stop confirming for this word
# >n
# Is sockeye.n.02 an appropriate substitute for fish? (y/n)
# It means: small salmon with red flesh; found in rivers and tributaries of the northern Pacific and valued as food; adults die after spawning
# Synonyms are: ['sockeye', 'sockeye salmon', 'red salmon', 'blueback salmon', 'Oncorhynchus nerka']
# >n
# Is brisling.n.02 an appropriate substitute for fish? (y/n)
# It means: small herring processed like a sardine
# Synonyms are: ['brisling', 'sprat', 'Clupea sprattus']
# >n
# Is sild.n.01 an appropriate substitute for fish? (y/n)
# It means: any of various young herrings (other than brislings) canned as sardines in Norway
# Synonyms are: ['sild']
# >
# Please type 'yes' or 'no' or 'x' to stop confirming for this word
# >n
# Is belted_sandfish.n.01 an appropriate substitute for fish? (y/n)
# It means: found in warm shallow waters of western Atlantic
# Synonyms are: ['belted sandfish', 'Serranus subligarius']
# >n
# Is black_sea_bass.n.01 an appropriate substitute for fish? (y/n)
# It means: bluish black-striped sea bass of the Atlantic coast of the United States
# Synonyms are: ['black sea bass', 'black bass', 'Centropistes striata']
# >n
# Is blackmouth_bass.n.01 an appropriate substitute for fish? (y/n)
# It means: small marine fish with black mouth and gill cavity
# Synonyms are: ['blackmouth bass', 'Synagrops bellus']
# >n
# Is grouper.n.02 an appropriate substitute for fish? (y/n)
# It means: usually solitary bottom sea basses of warm seas
# Synonyms are: ['grouper']
# >n
# Is rock_sea_bass.n.01 an appropriate substitute for fish? (y/n)
# It means: a kind of sea bass
# Synonyms are: ['rock sea bass', 'rock bass', 'Centropristis philadelphica']
# >n
# Is stone_bass.n.01 an appropriate substitute for fish? (y/n)
# It means: brown fish of the Atlantic and Mediterranean found around rocks and shipwrecks
# Synonyms are: ['stone bass', 'wreckfish', 'Polyprion americanus']
# >n
# Is striped_bass.n.02 an appropriate substitute for fish? (y/n)
# It means: marine food and game fish with dark longitudinal stripes; migrates upriver to spawn; sometimes placed in the genus Morone
# Synonyms are: ['striped bass', 'striper', 'Roccus saxatilis', 'rockfish']
# >y
# Is allice_shad.n.01 an appropriate substitute for fish? (y/n)
# It means: European shad
# Synonyms are: ['allice shad', 'allis shad', 'allice', 'allis', 'Alosa alosa']
# >y
# Is common_american_shad.n.01 an appropriate substitute for fish? (y/n)
# It means: shad of Atlantic coast of North America; naturalized to Pacific coast
# Synonyms are: ['common American shad', 'Alosa sapidissima']
# >y
# Is river_shad.n.01 an appropriate substitute for fish? (y/n)
# It means: shad that spawns in streams of the Mississippi drainage; very similar to Alosa sapidissima
# Synonyms are: ['river shad', 'Alosa chrysocloris']
# >y
# Is brook_trout.n.02 an appropriate substitute for fish? (y/n)
# It means: North American freshwater trout; introduced in Europe
# Synonyms are: ['brook trout', 'speckled trout', 'Salvelinus fontinalis']
# >y
# Is brown_trout.n.01 an appropriate substitute for fish? (y/n)
# It means: speckled trout of European rivers; introduced in North America
# Synonyms are: ['brown trout', 'salmon trout', 'Salmo trutta']
# >y
# Is lake_trout.n.02 an appropriate substitute for fish? (y/n)
# It means: large fork-tailed trout of lakes of Canada and the northern United States
# Synonyms are: ['lake trout', 'salmon trout', 'Salvelinus namaycush']
# >y
# Is rainbow_trout.n.02 an appropriate substitute for fish? (y/n)
# It means: found in Pacific coastal waters and streams from lower California to Alaska
# Synonyms are: ['rainbow trout', 'Salmo gairdneri']
# >y
# Is cisco.n.02 an appropriate substitute for fish? (y/n)
# It means: important food fish of cold deep lakes of North America
# Synonyms are: ['cisco', 'lake herring', 'Coregonus artedi']
# >y
# Is lake_whitefish.n.01 an appropriate substitute for fish? (y/n)
# It means: found in the Great Lakes and north to Alaska
# Synonyms are: ['lake whitefish', 'Coregonus clupeaformis']
# >y
# Is rocky_mountain_whitefish.n.01 an appropriate substitute for fish? (y/n)
# It means: whitefish of the western United States and Canada
# Synonyms are: ['Rocky Mountain whitefish', 'Prosopium williamsonii']
# >y
# Is round_whitefish.n.01 an appropriate substitute for fish? (y/n)
# It means: a whitefish with a bronze back; of northern North America and Siberia
# Synonyms are: ['round whitefish', 'Menominee whitefish', 'Prosopium cylindraceum']
# >n
# Is sea_trout.n.03 an appropriate substitute for fish? (y/n)
# It means: silvery marine variety of brown trout that migrates to fresh water to spawn
# Synonyms are: ['sea trout']
# >n
# First, pick the word sense for the word 'light'
# ==============
#
# Next, pick which hypernyms of ignite.v.01 we should allow players to use.
# ==============
# LIGHT
# Is burn.v.05 an appropriate substitute for light? (y/n)
# It means: cause to burn or combust
# Synonyms are: ['burn', 'combust']
# >y
# \Finally, pick which hyponyms of ignite.v.01 we should allow players to use.
# ==============
# LIGHT
# Is flare_up.v.01 an appropriate substitute for light? (y/n)
# It means: ignite quickly and suddenly, especially after having died down
# Synonyms are: ['flare up']
# >n
# Is kindle.v.02 an appropriate substitute for light? (y/n)
# It means: cause to start burning
# Synonyms are: ['kindle', 'enkindle', 'conflagrate', 'inflame']
# >y
# Is light_up.v.04 an appropriate substitute for light? (y/n)
# It means: ignite
# Synonyms are: ['light up']
# >y
# Is light_up.v.05 an appropriate substitute for light? (y/n)
# It means: begin to smoke
# Synonyms are: ['light up', 'fire up', 'light']
# >y
# Is reignite.v.01 an appropriate substitute for light? (y/n)
# It means: ignite anew, as of something burning
# Synonyms are: ['reignite']
# >y
# Is rekindle.v.01 an appropriate substitute for light? (y/n)
# It means: kindle anew, as of a fire
# Synonyms are: ['rekindle']
# >y
# First, pick the word sense for the word 'lamp'
# ==============
#
# Next, pick which hypernyms of lamp.n.01 we should allow players to use.
# ==============
# LAMP
# Is source_of_illumination.n.01 an appropriate substitute for lamp? (y/n)
# It means: any device serving as a source of visible electromagnetic radiation
# Synonyms are: ['source of illumination']
# >y
# Is device.n.01 an appropriate substitute for lamp? (y/n)
# It means: an instrumentality invented for a particular purpose
# Synonyms are: ['device']
# >y
# Is instrumentality.n.03 an appropriate substitute for lamp? (y/n)
# It means: an artifact (or system of artifacts) that is instrumental in accomplishing some end
# Synonyms are: ['instrumentality', 'instrumentation']
# >n
# \Finally, pick which hyponyms of lamp.n.01 we should allow players to use.
# ==============
# LAMP
# Is aladdin's_lamp.n.01 an appropriate substitute for lamp? (y/n)
# It means: (Arabian Nights) a magical lamp from which Aladdin summoned a genie
# Synonyms are: ["Aladdin's lamp"]
# >n
# Is candle.n.01 an appropriate substitute for lamp? (y/n)
# It means: stick of wax with a wick in the middle
# Synonyms are: ['candle', 'taper', 'wax light']
# >n
# Is discharge_lamp.n.01 an appropriate substitute for lamp? (y/n)
# It means: a lamp that generates light by a discharge between two electrodes in a gas
# Synonyms are: ['discharge lamp']
# >n
# Is electric_lamp.n.01 an appropriate substitute for lamp? (y/n)
# It means: a lamp powered by electricity
# Synonyms are: ['electric lamp']
# >n
# Is flash.n.10 an appropriate substitute for lamp? (y/n)
# It means: a lamp for providing momentary light to take a photograph
# Synonyms are: ['flash', 'photoflash', 'flash lamp', 'flashgun', 'flashbulb', 'flash bulb']
# >n
# Is fluorescent_lamp.n.01 an appropriate substitute for lamp? (y/n)
# It means: lamp consisting of a tube coated on the inside with a fluorescent material; mercury vapor in the tube emits ultraviolet radiation that is converted to visible radiation by the fluorescent material
# Synonyms are: ['fluorescent lamp']
# >n
# Is gas_lamp.n.01 an appropriate substitute for lamp? (y/n)
# It means: a lamp that burns illuminating gas
# Synonyms are: ['gas lamp']
# >y
# Is hurricane_lamp.n.01 an appropriate substitute for lamp? (y/n)
# It means: an oil lamp with a glass chimney and perforated metal lid to protect the flame from high winds; candlestick with a glass chimney
# Synonyms are: ['hurricane lamp', 'hurricane lantern', 'tornado lantern', 'storm lantern', 'storm lamp']
# >n
# Is lantern.n.01 an appropriate substitute for lamp? (y/n)
# It means: light in a transparent protective case
# Synonyms are: ['lantern']
# >y
# Is limelight.n.02 an appropriate substitute for lamp? (y/n)
# It means: a lamp consisting of a flame directed at a cylinder of lime with a lens to concentrate the light; formerly used for stage lighting
# Synonyms are: ['limelight', 'calcium light']
# >n
# Is neon_lamp.n.01 an appropriate substitute for lamp? (y/n)
# It means: a lamp consisting of a small gas-discharge tube containing neon at low pressure; luminescence is produced by the action of currents at high frequencies that are wrapped a few turns around the tube
# Synonyms are: ['neon lamp', 'neon induction lamp', 'neon tube']
# >n
# Is oil_lamp.n.01 an appropriate substitute for lamp? (y/n)
# It means: a lamp that burns oil (as kerosine) for light
# Synonyms are: ['oil lamp', 'kerosene lamp', 'kerosine lamp']
# >y
# Is sodium-vapor_lamp.n.01 an appropriate substitute for lamp? (y/n)
# It means: lamp in which an electric current passed through a tube of sodium vapor makes a yellow light; used is street lighting
# Synonyms are: ['sodium-vapor lamp', 'sodium-vapour lamp']
# >n
# Is spirit_lamp.n.01 an appropriate substitute for lamp? (y/n)
# It means: a lamp that burns a volatile liquid fuel such as alcohol
# Synonyms are: ['spirit lamp']
# >y
# Is spotlight.n.02 an appropriate substitute for lamp? (y/n)
# It means: a lamp that produces a strong beam of light to illuminate a restricted area; used to focus attention of a stage performer
# Synonyms are: ['spotlight', 'spot']
# >n
# Is streetlight.n.01 an appropriate substitute for lamp? (y/n)
# It means: a lamp supported on a lamppost; for illuminating a street
# Synonyms are: ['streetlight', 'street lamp']
# >n
# Is taillight.n.01 an appropriate substitute for lamp? (y/n)
# It means: lamp (usually red) mounted at the rear of a motor vehicle
# Synonyms are: ['taillight', 'tail lamp', 'rear light', 'rear lamp']
# >n
# Is chinese_lantern.n.01 an appropriate substitute for lamp? (y/n)
# It means: a collapsible paper lantern in bright colors; used for decorative purposes
# Synonyms are: ['Chinese lantern']
# >n
# Is dark_lantern.n.01 an appropriate substitute for lamp? (y/n)
# It means: a lantern with a single opening and a sliding panel that can be closed to conceal the light
# Synonyms are: ['dark lantern', "bull's-eye"]
# >n
# Is jack-o'-lantern.n.02 an appropriate substitute for lamp? (y/n)
# It means: lantern carved from a pumpkin
# Synonyms are: ["jack-o'-lantern"]
# >n
# Is safety_lamp.n.01 an appropriate substitute for lamp? (y/n)
# It means: an oil lamp that will not ignite flammable gases (methane)
# Synonyms are: ['safety lamp', 'Davy lamp']
# >n
# First, pick the word sense for the word 'give'
# ==============
#
# Next, pick which hypernyms of give.v.03 we should allow players to use.
# ==============
# GIVE
# Is transfer.v.05 an appropriate substitute for give? (y/n)
# It means: cause to change ownership
# Synonyms are: ['transfer']
# >y
# \Finally, pick which hyponyms of give.v.03 we should allow players to use.
# ==============
# GIVE
# Is accord.v.02 an appropriate substitute for give? (y/n)
# It means: allow to have
# Synonyms are: ['accord', 'allot', 'grant']
# >y
# Is allow.v.03 an appropriate substitute for give? (y/n)
# It means: let have
# Synonyms are: ['allow', 'grant']
# >y
# Is bestow.v.02 an appropriate substitute for give? (y/n)
# It means: give as a gift
# Synonyms are: ['bestow']
# >y
# Is concede.v.03 an appropriate substitute for give? (y/n)
# It means: give over; surrender or relinquish to the physical control of another
# Synonyms are: ['concede', 'yield', 'cede', 'grant']
# >y
# Is contribute.v.02 an appropriate substitute for give? (y/n)
# It means: contribute to some cause
# Synonyms are: ['contribute', 'give', 'chip in', 'kick in']
# >n
# Is cough_up.v.01 an appropriate substitute for give? (y/n)
# It means: give reluctantly
# Synonyms are: ['cough up', 'pony up', 'spit up']
# >y
# Is deposit.v.02 an appropriate substitute for give? (y/n)
# It means: put into a bank account
# Synonyms are: ['deposit', 'bank']
# >n
# Is distribute.v.01 an appropriate substitute for give? (y/n)
# It means: administer or bestow, as in small portions
# Synonyms are: ['distribute', 'administer', 'mete out', 'deal', 'parcel out', 'lot', 'dispense', 'shell out', 'deal out', 'dish out', 'allot', 'dole out']
# >n
# Is enfeoff.v.01 an appropriate substitute for give? (y/n)
# It means: put in possession of land in exchange for a pledge of service, in feudal society
# Synonyms are: ['enfeoff']
# >n
# Is heap.v.01 an appropriate substitute for give? (y/n)
# It means: bestow in large quantities
# Synonyms are: ['heap']
# >n
# Is lease.v.03 an appropriate substitute for give? (y/n)
# It means: grant use or occupation of under a term of contract
# Synonyms are: ['lease', 'let', 'rent']
# >n
# Is lend.v.02 an appropriate substitute for give? (y/n)
# It means: give temporarily; let have for a limited time
# Synonyms are: ['lend', 'loan']
# >n
# Is offer.v.02 an appropriate substitute for give? (y/n)
# It means: present for acceptance or rejection
# Synonyms are: ['offer', 'proffer']
# >y
# Is pay.v.01 an appropriate substitute for give? (y/n)
# It means: give money, usually in exchange for goods or services
# Synonyms are: ['pay']
# >n
# Is present.v.04 an appropriate substitute for give? (y/n)
# It means: hand over formally
# Synonyms are: ['present', 'submit']
# >y
# Is provide.v.02 an appropriate substitute for give? (y/n)
# It means: give what is desired or needed, especially support, food or sustenance
# Synonyms are: ['provide', 'supply', 'ply', 'cater']
# >y
# Is render.v.07 an appropriate substitute for give? (y/n)
# It means: give back
# Synonyms are: ['render', 'return']
# >n
# Is requite.v.01 an appropriate substitute for give? (y/n)
# It means: make repayment for or return something
# Synonyms are: ['requite', 'repay']
# >n
# Is spare.v.03 an appropriate substitute for give? (y/n)
# It means: give up what is not strictly needed
# Synonyms are: ['spare', 'give up', 'part with', 'dispense with']
# >n
# Is supply.v.01 an appropriate substitute for give? (y/n)
# It means: give something useful or necessary to
# Synonyms are: ['supply', 'provide', 'render', 'furnish']
# >y
# Is support.v.02 an appropriate substitute for give? (y/n)
# It means: support materially or financially
# Synonyms are: ['support']
# >n
# Is vest.v.02 an appropriate substitute for give? (y/n)
# It means: place (authority, property, or rights) in the control of a person or group of persons
# Synonyms are: ['vest']
# >y
# Is enfranchise.v.02 an appropriate substitute for give? (y/n)
# It means: grant voting rights
# Synonyms are: ['enfranchise']
# >n
# Is give.v.35 an appropriate substitute for give? (y/n)
# It means: accord by verdict
# Synonyms are: ['give']
# >n
# Is allowance.v.01 an appropriate substitute for give? (y/n)
# It means: put on a fixed allowance, as of food
# Synonyms are: ['allowance']
# >n
# Is vouchsafe.v.01 an appropriate substitute for give? (y/n)
# It means: grant in a condescending manner
# Synonyms are: ['vouchsafe']
# >n
# Is give.v.44 an appropriate substitute for give? (y/n)
# It means: proffer (a body part)
# Synonyms are: ['give']
# >y
# Is tender.v.03 an appropriate substitute for give? (y/n)
# It means: make a tender of; in legal settlements
# Synonyms are: ['tender']
# >n
# Is bring_in.v.04 an appropriate substitute for give? (y/n)
# It means: submit (a verdict) to a court
# Synonyms are: ['bring in']
# >n
# Is accommodate.v.03 an appropriate substitute for give? (y/n)
# It means: provide with something desired or needed
# Synonyms are: ['accommodate']
# >n
# Is board.v.04 an appropriate substitute for give? (y/n)
# It means: provide food and lodging (for)
# Synonyms are: ['board']
# >n
# Is cater.v.02 an appropriate substitute for give? (y/n)
# It means: supply food ready to eat; for parties and banquets
# Synonyms are: ['cater']
# >n
# Is drench.v.02 an appropriate substitute for give? (y/n)
# It means: force to drink
# Synonyms are: ['drench']
# >n
# Is feed.v.01 an appropriate substitute for give? (y/n)
# It means: provide as food
# Synonyms are: ['feed']
# >n
# Is feed.v.02 an appropriate substitute for give? (y/n)
# It means: give food to
# Synonyms are: ['feed', 'give']
# >n
# Is feed.v.07 an appropriate substitute for give? (y/n)
# It means: serve as food for; be the food for
# Synonyms are: ['feed']
# >n
# Is fix_up.v.01 an appropriate substitute for give? (y/n)
# It means: find (something or someone) for
# Synonyms are: ['fix up']
# >n
# Is gratify.v.02 an appropriate substitute for give? (y/n)
# It means: yield (to); give satisfaction to
# Synonyms are: ['gratify', 'pander', 'indulge']
# >n
# Is gutter.v.04 an appropriate substitute for give? (y/n)
# It means: provide with gutters
# Synonyms are: ['gutter']
# >n
# ...
# It means: furnish with glass
# Synonyms are: ['glass', 'glaze']
# >n
# Is grate.v.01 an appropriate substitute for give? (y/n)
# It means: furnish with a grate
# Synonyms are: ['grate']
# >n
# Is hat.v.02 an appropriate substitute for give? (y/n)
# It means: furnish with a hat
# Synonyms are: ['hat']
# >n
# Is headline.v.02 an appropriate substitute for give? (y/n)
# It means: provide (a newspaper page or a story) with a headline
# Synonyms are: ['headline']
# >n
# Is headquarter.v.01 an appropriate substitute for give? (y/n)
# It means: provide with headquarters
# Synonyms are: ['headquarter']
# >n
# Is heat.v.02 an appropriate substitute for give? (y/n)
# It means: provide with heat
# Synonyms are: ['heat']
# >n
# Is hobnail.v.01 an appropriate substitute for give? (y/n)
# It means: supply with hobnails
# Synonyms are: ['hobnail']
# >n
# Is hydrate.v.01 an appropriate substitute for give? (y/n)
# It means: supply water or liquid to in order to maintain a healthy balance
# Synonyms are: ['hydrate']
# >n
# Is index.v.02 an appropriate substitute for give? (y/n)
# It means: provide with an index
# Synonyms are: ['index']
# >n
# Is innervate.v.01 an appropriate substitute for give? (y/n)
# It means: supply nerves to (some organ or body part)
# Synonyms are: ['innervate']
# >n
# Is interleave.v.01 an appropriate substitute for give? (y/n)
# It means: provide (books) with blank leaves
# Synonyms are: ['interleave']
# >n
# Is joint.v.02 an appropriate substitute for give? (y/n)
# It means: provide with a joint
# Synonyms are: ['joint', 'articulate']
# >n
# Is kern.v.01 an appropriate substitute for give? (y/n)
# It means: furnish with a kern
# Synonyms are: ['kern']
# >n
# Is key.v.02 an appropriate substitute for give? (y/n)
# It means: provide with a key
# Synonyms are: ['key']
# >n
# Is leverage.v.02 an appropriate substitute for give? (y/n)
# It means: provide with leverage
# Synonyms are: ['leverage']
# >n
# Is machicolate.v.01 an appropriate substitute for give? (y/n)
# It means: supply with projecting galleries
# Synonyms are: ['machicolate']
# >n
# Is match.v.02 an appropriate substitute for give? (y/n)
# It means: provide funds complementary to
# Synonyms are: ['match']
# >n
# Is offer.v.01 an appropriate substitute for give? (y/n)
# It means: make available or accessible, provide or furnish
# Synonyms are: ['offer']
# >n
# Is partner.v.01 an appropriate substitute for give? (y/n)
# It means: provide with a partner
# Synonyms are: ['partner']
# >n
# Is patch.v.02 an appropriate substitute for give? (y/n)
# It means: provide with a patch; also used metaphorically
# Synonyms are: ['patch']
# >n
# Is pour.v.05 an appropriate substitute for give? (y/n)
# It means: supply in large amounts or quantities
# Synonyms are: ['pour']
# >n
# Is provision.v.01 an appropriate substitute for give? (y/n)
# It means: supply with provisions
# Synonyms are: ['provision', 'purvey']
# >n
# Is pump.v.04 an appropriate substitute for give? (y/n)
# It means: supply in great quantities
# Synonyms are: ['pump']
# >n
# Is rafter.v.01 an appropriate substitute for give? (y/n)
# It means: provide (a ceiling) with rafters
# Synonyms are: ['rafter']
# >n
# Is rail.v.03 an appropriate substitute for give? (y/n)
# It means: provide with rails
# Synonyms are: ['rail']
# >n
# Is railroad.v.02 an appropriate substitute for give? (y/n)
# It means: supply with railroad lines
# Synonyms are: ['railroad']
# >n
# Is ramp.v.02 an appropriate substitute for give? (y/n)
# It means: furnish with a ramp
# Synonyms are: ['ramp']
# >n
# Is reflectorize.v.01 an appropriate substitute for give? (y/n)
# It means: provide with reflectors, such as chemicals
# Synonyms are: ['reflectorize', 'reflectorise']
# >n
# Is retrofit.v.01 an appropriate substitute for give? (y/n)
# It means: provide with parts, devices, or equipment not available or in use at the time of the original manufacture
# Synonyms are: ['retrofit']
# >n
# Is rim.v.02 an appropriate substitute for give? (y/n)
# It means: furnish with a rim
# Synonyms are: ['rim']
# >n
# Is sanitate.v.01 an appropriate substitute for give? (y/n)
# It means: provide with sanitary facilities or appliances
# Synonyms are: ['sanitate']
# >
# Please type 'yes' or 'no' or 'x' to stop confirming for this word
# >n
# Is seat.v.04 an appropriate substitute for give? (y/n)
# It means: put a seat on a chair
# Synonyms are: ['seat']
# >n
# Is seat.v.05 an appropriate substitute for give? (y/n)
# It means: provide with seats
# Synonyms are: ['seat']
# >n
# Is shelter.v.01 an appropriate substitute for give? (y/n)
# It means: provide shelter for
# Synonyms are: ['shelter']
# >n
# Is signalize.v.01 an appropriate substitute for give? (y/n)
# It means: provide with traffic signals
# Synonyms are: ['signalize', 'signalise']
# >n
# Is slat.v.01 an appropriate substitute for give? (y/n)
# It means: equip or bar with slats
# Synonyms are: ['slat']
# >n
# Is step.v.05 an appropriate substitute for give? (y/n)
# It means: furnish with steps
# Synonyms are: ['step']
# >n
# Is stint.v.02 an appropriate substitute for give? (y/n)
# It means: supply sparingly and with restricted quantities
# Synonyms are: ['stint', 'skimp', 'scant']
# >n
# Is stock.v.03 an appropriate substitute for give? (y/n)
# It means: supply with fish
# Synonyms are: ['stock']
# >n
# Is stock.v.04 an appropriate substitute for give? (y/n)
# It means: supply with livestock
# Synonyms are: ['stock']
# >n
# Is stock.v.05 an appropriate substitute for give? (y/n)
# It means: amass so as to keep for future use or sale or for a particular occasion or use
# Synonyms are: ['stock', 'buy in', 'stock up']
# >n
# Is stock.v.06 an appropriate substitute for give? (y/n)
# It means: provide or furnish with a stock of something
# Synonyms are: ['stock']
# >n
# Is subtitle.v.01 an appropriate substitute for give? (y/n)
# It means: supply (a movie) with subtitles
# Synonyms are: ['subtitle']
# >n
# Is surfeit.v.01 an appropriate substitute for give? (y/n)
# It means: supply or feed to surfeit
# Synonyms are: ['surfeit', 'cloy']
# >n
# Is tap.v.06 an appropriate substitute for give? (y/n)
# It means: furnish with a tap or spout, so as to be able to draw liquid from it
# Synonyms are: ['tap']
# >n
# Is terrace.v.01 an appropriate substitute for give? (y/n)
# It means: provide (a house) with a terrace
# Synonyms are: ['terrace', 'terrasse']
# >n
# Is theme.v.01 an appropriate substitute for give? (y/n)
# It means: provide with a particular theme or motive
# Synonyms are: ['theme']
# >n
# Is ticket.v.02 an appropriate substitute for give? (y/n)
# It means: provide with a ticket for passage or admission
# Synonyms are: ['ticket']
# >n
# Is toggle.v.01 an appropriate substitute for give? (y/n)
# It means: provide with a toggle or toggles
# Synonyms are: ['toggle']
# >n
# Is tool.v.03 an appropriate substitute for give? (y/n)
# It means: furnish with tools
# Synonyms are: ['tool']
# >n
# Is top.v.05 an appropriate substitute for give? (y/n)
# It means: provide with a top or finish the top (of a structure)
# Synonyms are: ['top', 'top out']
# >n
# Is transistorize.v.01 an appropriate substitute for give? (y/n)
# It means: equip (an electronic circuit or device) with transistors
# Synonyms are: ['transistorize', 'transistorise']
# >n
# Is tube.v.01 an appropriate substitute for give? (y/n)
# It means: provide with a tube or insert a tube into
# Synonyms are: ['tube']
# >n
# Is uniform.v.01 an appropriate substitute for give? (y/n)
# It means: provide with uniforms
# Synonyms are: ['uniform']
# >n
# Is upholster.v.01 an appropriate substitute for give? (y/n)
# It means: provide furniture with padding, springs, webbing, and covers
# Synonyms are: ['upholster']
# >n
# Is victual.v.01 an appropriate substitute for give? (y/n)
# It means: supply with food
# Synonyms are: ['victual']
# >n
# Is water.v.02 an appropriate substitute for give? (y/n)
# It means: provide with water
# Synonyms are: ['water']
# >n
# Is wharf.v.01 an appropriate substitute for give? (y/n)
# It means: provide with a wharf
# Synonyms are: ['wharf']
# >n
# Is wive.v.03 an appropriate substitute for give? (y/n)
# It means: provide with a wife; marry (someone) to a wife
# Synonyms are: ['wive']
# >n
# Is yield.v.01 an appropriate substitute for give? (y/n)
# It means: be the cause or source of
# Synonyms are: ['yield', 'give', 'afford']
# >n
# Is plank.v.03 an appropriate substitute for give? (y/n)
# It means: cook and serve on a plank
# Synonyms are: ['plank']
# >n
# Is accouter.v.01 an appropriate substitute for give? (y/n)
# It means: provide with military equipment
# Synonyms are: ['accouter', 'accoutre']
# >n
# Is appoint.v.03 an appropriate substitute for give? (y/n)
# It means: furnish
# Synonyms are: ['appoint']
# >n
# Is armor.v.01 an appropriate substitute for give? (y/n)
# It means: equip with armor
# Synonyms are: ['armor', 'armour']
# >n
# Is collar.v.03 an appropriate substitute for give? (y/n)
# It means: furnish with a collar
# Synonyms are: ['collar']
# >n
# Is commission.v.01 an appropriate substitute for give? (y/n)
# It means: put into commission; equip for service; of ships
# Synonyms are: ['commission']
# >n
# Is fin.v.01 an appropriate substitute for give? (y/n)
# It means: equip (a car) with fins
# Synonyms are: ['fin']
# >n
# Is fuse.v.03 an appropriate substitute for give? (y/n)
# It means: equip with a fuse; provide with a fuse
# Synonyms are: ['fuse']
# >n
# Is horseshoe.v.01 an appropriate substitute for give? (y/n)
# It means: equip (a horse) with a horseshoe or horseshoes
# Synonyms are: ['horseshoe']
# >n
# Is instrument.v.01 an appropriate substitute for give? (y/n)
# It means: equip with instruments for measuring, recording, or controlling
# Synonyms are: ['instrument']
# >n
# Is invest.v.03 an appropriate substitute for give? (y/n)
# It means: furnish with power or authority; of kings or emperors
# Synonyms are: ['invest', 'clothe', 'adorn']
# >n
# Is kit_out.v.01 an appropriate substitute for give? (y/n)
# It means: supply with a set of articles or tools
# Synonyms are: ['kit out', 'kit up', 'kit']
# >n
# Is mechanize.v.01 an appropriate substitute for give? (y/n)
# It means: equip with armed and armored motor vehicles
# Synonyms are: ['mechanize', 'mechanise', 'motorize', 'motorise']
# >n
# Is motorize.v.01 an appropriate substitute for give? (y/n)
# It means: equip with a motor vehicle
# Synonyms are: ['motorize']
# >n
# Is motorize.v.02 an appropriate substitute for give? (y/n)
# It means: equip with a motor
# Synonyms are: ['motorize']
# >n
# Is muzzle.v.01 an appropriate substitute for give? (y/n)
# It means: fit with a muzzle
# Synonyms are: ['muzzle']
# >n
# Is re-equip.v.01 an appropriate substitute for give? (y/n)
# It means: re-equip a factory or plant
# Synonyms are: ['re-equip', 'rejig']
# >n
# Is refit.v.01 an appropriate substitute for give? (y/n)
# It means: fit out again
# Synonyms are: ['refit']
# >n
# Is rig.v.04 an appropriate substitute for give? (y/n)
# It means: equip with sails or masts
# Synonyms are: ['rig', 'set', 'set up']
# >n
# Is shaft.v.01 an appropriate substitute for give? (y/n)
# It means: equip with a shaft
# Synonyms are: ['shaft']
# >n
# Is spar.v.01 an appropriate substitute for give? (y/n)
# It means: furnish with spars
# Synonyms are: ['spar']
# >n
# Is spur.v.05 an appropriate substitute for give? (y/n)
# It means: equip with spurs
# Synonyms are: ['spur']
# >n
# Is stave.v.01 an appropriate substitute for give? (y/n)
# It means: furnish with staves
# Synonyms are: ['stave']
# >n
# Is stock.v.02 an appropriate substitute for give? (y/n)
# It means: equip with a stock
# Synonyms are: ['stock']
# >n
# Is turn_out.v.09 an appropriate substitute for give? (y/n)
# It means: outfit or equip, as with accessories
# Synonyms are: ['turn out']
# >n
# Is wire.v.01 an appropriate substitute for give? (y/n)
# It means: provide with electrical circuits
# Synonyms are: ['wire']
# >n
# First, pick the word sense for the word 'troll'
# ==============
#
# Next, pick which hypernyms of troll.n.01 we should allow players to use.
# ==============
# TROLL
# Is mythical_monster.n.01 an appropriate substitute for troll? (y/n)
# It means: a monster renowned in folklore and myth
# Synonyms are: ['mythical monster', 'mythical creature']
# >y
# Is monster.n.01 an appropriate substitute for troll? (y/n)
# It means: an imaginary creature usually having various human and animal parts
# Synonyms are: ['monster']
# >y
# Is mythical_being.n.01 an appropriate substitute for troll? (y/n)
# It means: an imaginary being of myth or fable
# Synonyms are: ['mythical being']
# >y
# Is imaginary_being.n.01 an appropriate substitute for troll? (y/n)
# It means: a creature of the imagination; a person that exists only in legends or myths or fiction
# Synonyms are: ['imaginary being', 'imaginary creature']
# >n
# Is imaginary_being.n.01 an appropriate substitute for troll? (y/n)
# It means: a creature of the imagination; a person that exists only in legends or myths or fiction
# Synonyms are: ['imaginary being', 'imaginary creature']
# >n
# \Finally, pick which hyponyms of troll.n.01 we should allow players to use.
# ==============
# TROLL
# First, pick the word sense for the word 'propose'
# ==============
#
# Next, pick which hypernyms of propose.v.05 we should allow players to use.
# ==============
# PROPOSE
# Is request.v.02 an appropriate substitute for propose? (y/n)
# It means: ask (a person) to do something
# Synonyms are: ['request']
# >y
# Is ask.v.02 an appropriate substitute for propose? (y/n)
# It means: make a request or demand for something to somebody
# Synonyms are: ['ask']
# >y
# Is request.v.01 an appropriate substitute for propose? (y/n)
# It means: express the need or desire for; ask for
# Synonyms are: ['request', 'bespeak', 'call for', 'quest']
# >n
# \Finally, pick which hyponyms of propose.v.05 we should allow players to use.
# ==============
# PROPOSE
# First, pick the word sense for the word 'princess'
# ==============
#
# Next, pick which hypernyms of princess.n.01 we should allow players to use.
# ==============
# PRINCESS
# Is aristocrat.n.01 an appropriate substitute for princess? (y/n)
# It means: a member of the aristocracy
# Synonyms are: ['aristocrat', 'blue blood', 'patrician']
# >y
# Is leader.n.01 an appropriate substitute for princess? (y/n)
# It means: a person who rules or guides or inspires others
# Synonyms are: ['leader']
# >n
# \Finally, pick which hyponyms of princess.n.01 we should allow players to use.
# ==============
# PRINCESS
# Is archduchess.n.01 an appropriate substitute for princess? (y/n)
# It means: a wife or widow of an archduke or a princess of the former ruling house of Austria
# Synonyms are: ['archduchess']
# >n
# Is crown_princess.n.02 an appropriate substitute for princess? (y/n)
# It means: a female heir apparent to a throne
# Synonyms are: ['crown princess']
# >y
# Is maharani.n.01 an appropriate substitute for princess? (y/n)
# It means: a great rani; a princess in India or the wife of a maharaja
# Synonyms are: ['maharani', 'maharanee']
# >y
# Is princess_royal.n.01 an appropriate substitute for princess? (y/n)
# It means: the eldest daughter of a British sovereign
# Synonyms are: ['princess royal']
# >n
# First, pick the word sense for the word 'go'
# ==============
#
# Next, pick which hypernyms of go.v.03 we should allow players to use.
# ==============
# GO
# Is exit.v.01 an appropriate substitute for go? (y/n)
# It means: move out of or depart from
# Synonyms are: ['exit', 'go out', 'get out', 'leave']
# >n
# \Finally, pick which hyponyms of go.v.03 we should allow players to use.
# ==============
# GO
# Is shove_off.v.01 an appropriate substitute for go? (y/n)
# It means: leave; informal or rude
# Synonyms are: ['shove off', 'shove along', 'blow']
# >n
# First, pick the word sense for the word 'north'
# ==============
#
# Next, pick which hypernyms of north.r.01 we should allow players to use.
# ==============
# NORTH
# \Finally, pick which hyponyms of north.r.01 we should allow players to use.
# ==============
# NORTH
# You're done annotating!  Save your annotation to your Google drive.
# You need to paste in a confirmation code to allow Colab to have access.
# We'll create a file called 'word-sense-annotations.json' for you to turn in.
# ==============
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/

# %% [markdown]
# ## Look Over Your Annotations
#
# Here's what your selections were, and what their corresponding synonyms are.

# %%
for word in word_senses:
  print('\n', word.upper())
  word_sense = wn.synset(word_senses[word])
  print('Synonyms:\t', get_synonyms(word_sense))
  print('Hypernyms:', )
  for hypernym in confirmed_hypernyms[word]:
    print('\t', get_synonyms(wn.synset(hypernym)))

  print('Hyponyms:', )
  hyponyms = confirmed_hyponyms[word]
  for hyponym in hyponyms:
    print('\t', get_synonyms(wn.synset(hyponym)))
# Out:
#  WEAR
# Synonyms:	 ['wear', 'wearing']
# Hypernyms:
# Hyponyms:
#
#  CROWN
# Synonyms:	 ['crown']
# Hypernyms:
# Hyponyms:
#
#  SMELL
# Synonyms:	 ['smell']
# Hypernyms:
# 	 ['perceive', 'comprehend']
# Hyponyms:
# 	 ['get a noseful', 'get a whiff']
# 	 ['scent', 'nose', 'wind']
# 	 ['sniff', 'whiff']
# 	 ['snuff', 'snuffle']
#
#  ROSE
# Synonyms:	 ['rose', 'rosebush']
# Hypernyms:
# Hyponyms:
# 	 ['China rose', 'Bengal rose', 'Rosa chinensis']
# 	 ['damask rose', 'summer damask rose', 'Rosa damascena']
# 	 ['dog rose', 'Rosa canina']
# 	 ['mountain rose', 'Rosa pendulina']
# 	 ['multiflora', 'multiflora rose', 'Japanese rose', 'baby rose', 'Rosa multiflora']
# 	 ['musk rose', 'Rosa moschata']
# 	 ['sweetbrier', 'sweetbriar', 'brier', 'briar', 'eglantine', 'Rosa eglanteria']
#
#  EAT
# Synonyms:	 ['eat']
# Hypernyms:
# 	 ['consume', 'ingest', 'take in', 'take', 'have']
# 	 ['eat']
# 	 ['consume', 'ingest', 'take in', 'take', 'have']
# Hyponyms:
# 	 ['devour', 'down', 'consume', 'go through']
# 	 ['devour', 'guttle', 'raven', 'pig']
# 	 ['eat up', 'finish', 'polish off']
# 	 ['fare']
# 	 ['fill up', 'fill']
# 	 ['gluttonize', 'gluttonise', 'fress']
# 	 ['gobble', 'bolt']
# 	 ['nibble', 'pick', 'piece']
# 	 ['pitch in', 'dig in']
# 	 ['slurp']
# 	 ['wolf', 'wolf down']
#
#  FISH
# Synonyms:	 ['fish']
# Hypernyms:
# 	 ['aquatic vertebrate']
# 	 ['vertebrate', 'craniate']
# 	 ['chordate']
# 	 ['animal', 'animate being', 'beast', 'brute', 'creature', 'fauna']
# 	 ['organism', 'being']
# 	 ['living thing', 'animate thing']
# Hyponyms:
# 	 ['bony fish']
# 	 ['food fish']
# 	 ['game fish', 'sport fish']
# 	 ['young fish']
# 	 ['herring', 'Clupea harangus']
# 	 ['salmon']
# 	 ['sardine']
# 	 ['sea bass']
# 	 ['shad']
# 	 ['trout']
# 	 ['whitefish']
# 	 ['parr']
# 	 ['whitebait']
# 	 ['striped bass', 'striper', 'Roccus saxatilis', 'rockfish']
# 	 ['allice shad', 'allis shad', 'allice', 'allis', 'Alosa alosa']
# 	 ['common American shad', 'Alosa sapidissima']
# 	 ['river shad', 'Alosa chrysocloris']
# 	 ['brook trout', 'speckled trout', 'Salvelinus fontinalis']
# 	 ['brown trout', 'salmon trout', 'Salmo trutta']
# 	 ['lake trout', 'salmon trout', 'Salvelinus namaycush']
# 	 ['rainbow trout', 'Salmo gairdneri']
# 	 ['cisco', 'lake herring', 'Coregonus artedi']
# 	 ['lake whitefish', 'Coregonus clupeaformis']
# 	 ['Rocky Mountain whitefish', 'Prosopium williamsonii']
#
#  LIGHT
# Synonyms:	 ['ignite', 'light']
# Hypernyms:
# 	 ['burn', 'combust']
# Hyponyms:
# 	 ['kindle', 'enkindle', 'conflagrate', 'inflame']
# 	 ['light up']
# 	 ['light up', 'fire up', 'light']
# 	 ['reignite']
# 	 ['rekindle']
#
#  LAMP
# Synonyms:	 ['lamp']
# Hypernyms:
# 	 ['source of illumination']
# 	 ['device']
# Hyponyms:
# 	 ['gas lamp']
# 	 ['lantern']
# 	 ['oil lamp', 'kerosene lamp', 'kerosine lamp']
# 	 ['spirit lamp']
#
#  GIVE
# Synonyms:	 ['give']
# Hypernyms:
# 	 ['transfer']
# Hyponyms:
# 	 ['accord', 'allot', 'grant']
# 	 ['allow', 'grant']
# 	 ['bestow']
# 	 ['concede', 'yield', 'cede', 'grant']
# 	 ['cough up', 'pony up', 'spit up']
# 	 ['offer', 'proffer']
# 	 ['present', 'submit']
# 	 ['provide', 'supply', 'ply', 'cater']
# 	 ['supply', 'provide', 'render', 'furnish']
# 	 ['vest']
# 	 ['give']
# 	 ['serve', 'serve up', 'dish out', 'dish up', 'dish']
# 	 ['equip', 'fit', 'fit out', 'outfit']
# 	 ['extend', 'offer']
#
#  TROLL
# Synonyms:	 ['troll']
# Hypernyms:
# 	 ['mythical monster', 'mythical creature']
# 	 ['monster']
# 	 ['mythical being']
# Hyponyms:
#
#  PROPOSE
# Synonyms:	 ['propose', 'declare oneself', 'offer', 'pop the question']
# Hypernyms:
# 	 ['request']
# 	 ['ask']
# Hyponyms:
#
#  PRINCESS
# Synonyms:	 ['princess']
# Hypernyms:
# 	 ['aristocrat', 'blue blood', 'patrician']
# Hyponyms:
# 	 ['crown princess']
# 	 ['maharani', 'maharanee']
#
#  GO
# Synonyms:	 ['go', 'go away', 'depart']
# Hypernyms:
# Hyponyms:
#
#  NORTH
# Synonyms:	 ['north', 'northerly', 'northwards', 'northward']
# Hypernyms:
# Hyponyms:

# %% [markdown]
# ## Enumerate Alternatives Wordings of Commands
#
# Once we know what the word sense is for each word in our command, and what its relevant hypernyms and hyponyms are, we can output a rich set of reasonably accurate paraphrases for the commands in our game.
#
# Here we use the

# %%
import itertools #We're using the product method from itertools

def get_alternatives(word, word_senses, confirmed_hypernyms, confirmed_hyponyms):
  """Create a list of good alternatives for a word by listing out the synonyms
    for its word sense, and for its hyponyms and hypernyms."""
  alternatives = []
  if not word in word_senses:
    alternatives.append(word)
    return alternatives
  word_sense = wn.synset(word_senses[word])
  alternatives.extend(get_synonyms(word_sense))
  for hypernym in confirmed_hypernyms[word]:
    alternatives.extend(get_synonyms(wn.synset(hypernym)))
  for hyponym in confirmed_hyponyms[word]:
    alternatives.extend(get_synonyms(wn.synset(hyponym)))
  return alternatives

def enumerate_alternatives(sentence, word_senses, confirmed_hypernyms, confirmed_hyponyms):
  """Enumerate all of the sentenes that can result by taking any combination of
     the alternates for each word in the sentence."""
  words = word_tokenize(sentence.lower())
  # a list of lists
  alternatives_per_word = []
  for word in words:
    alternatives = get_alternatives(word, word_senses, confirmed_hypernyms, confirmed_hyponyms)
    alternatives_per_word.append(alternatives)
  
  alternative_to_original = {}
  # all combinations of a list of lists
  for words in list(itertools.product(*alternatives_per_word)):
    alt_sent = " ".join(words)
    alternative_to_original[alt_sent] = sentence
  return alternative_to_original


# alternative_commands is a dictionary that maps 
# the new commands onto the original ones.
alternative_commands = {}
for command in commands:
  alternative_commands.update(enumerate_alternatives(command, 
                                                     word_senses, 
                                                     confirmed_hypernyms, 
                                                     confirmed_hyponyms))

for alt_sent in alternative_commands:
  print("%s ==> %s" % (alt_sent, alternative_commands[alt_sent]))
print("Congratulations you can now handle %d commands instead of just %d!" % 
      (len(alternative_commands.keys()), len(commands)))
# Out:
# wear crown ==> wear crown
# wearing crown ==> wear crown
# smell rose ==> smell rose
# smell rosebush ==> smell rose
# smell China rose ==> smell rose
# smell Bengal rose ==> smell rose
# smell Rosa chinensis ==> smell rose
# smell damask rose ==> smell rose
# smell summer damask rose ==> smell rose
# smell Rosa damascena ==> smell rose
# smell dog rose ==> smell rose
# smell Rosa canina ==> smell rose
# smell mountain rose ==> smell rose
# smell Rosa pendulina ==> smell rose
# smell multiflora ==> smell rose
# smell multiflora rose ==> smell rose
# smell Japanese rose ==> smell rose
# smell baby rose ==> smell rose
# smell Rosa multiflora ==> smell rose
# smell musk rose ==> smell rose
# smell Rosa moschata ==> smell rose
# smell sweetbrier ==> smell rose
# smell sweetbriar ==> smell rose
# smell brier ==> smell rose
# smell briar ==> smell rose
# smell eglantine ==> smell rose
# smell Rosa eglanteria ==> smell rose
# perceive rose ==> smell rose
# perceive rosebush ==> smell rose
# perceive China rose ==> smell rose
# perceive Bengal rose ==> smell rose
# perceive Rosa chinensis ==> smell rose
# perceive damask rose ==> smell rose
# perceive summer damask rose ==> smell rose
# perceive Rosa damascena ==> smell rose
# perceive dog rose ==> smell rose
# perceive Rosa canina ==> smell rose
# perceive mountain rose ==> smell rose
# perceive Rosa pendulina ==> smell rose
# perceive multiflora ==> smell rose
# perceive multiflora rose ==> smell rose
# perceive Japanese rose ==> smell rose
# perceive baby rose ==> smell rose
# perceive Rosa multiflora ==> smell rose
# perceive musk rose ==> smell rose
# perceive Rosa moschata ==> smell rose
# perceive sweetbrier ==> smell rose
# perceive sweetbriar ==> smell rose
# perceive brier ==> smell rose
# perceive briar ==> smell rose
# perceive eglantine ==> smell rose
# perceive Rosa eglanteria ==> smell rose
# comprehend rose ==> smell rose
# comprehend rosebush ==> smell rose
# comprehend China rose ==> smell rose
# comprehend Bengal rose ==> smell rose
# comprehend Rosa chinensis ==> smell rose
# comprehend damask rose ==> smell rose
# comprehend summer damask rose ==> smell rose
# comprehend Rosa damascena ==> smell rose
# comprehend dog rose ==> smell rose
# comprehend Rosa canina ==> smell rose
# comprehend mountain rose ==> smell rose
# eat whitebait ==> eat fish
# eat striped bass ==> eat fish
# eat striper ==> eat fish
# eat Roccus saxatilis ==> eat fish
# eat rockfish ==> eat fish
# eat allice shad ==> eat fish
# eat allis shad ==> eat fish
# eat allice ==> eat fish
# eat allis ==> eat fish
# eat Alosa alosa ==> eat fish
# eat common American shad ==> eat fish
# eat Alosa sapidissima ==> eat fish
# eat river shad ==> eat fish
# eat Alosa chrysocloris ==> eat fish
# eat brook trout ==> eat fish
# eat speckled trout ==> eat fish
# eat Salvelinus fontinalis ==> eat fish
# eat brown trout ==> eat fish
# eat salmon trout ==> eat fish
# eat Salmo trutta ==> eat fish
# eat lake trout ==> eat fish
# eat Salvelinus namaycush ==> eat fish
# eat rainbow trout ==> eat fish
# eat Salmo gairdneri ==> eat fish
# eat cisco ==> eat fish
# eat lake herring ==> eat fish
# eat Coregonus artedi ==> eat fish
# eat lake whitefish ==> eat fish
# eat Coregonus clupeaformis ==> eat fish
# eat Rocky Mountain whitefish ==> eat fish
# eat Prosopium williamsonii ==> eat fish
# consume fish ==> eat fish
# consume aquatic vertebrate ==> eat fish
# consume vertebrate ==> eat fish
# consume craniate ==> eat fish
# consume chordate ==> eat fish
# consume animal ==> eat fish
# consume animate being ==> eat fish
# consume beast ==> eat fish
# consume brute ==> eat fish
# consume creature ==> eat fish
# consume fauna ==> eat fish
# consume organism ==> eat fish
# consume being ==> eat fish
# consume living thing ==> eat fish
# consume animate thing ==> eat fish
# consume bony fish ==> eat fish
# consume food fish ==> eat fish
# consume game fish ==> eat fish
# consume sport fish ==> eat fish
# consume young fish ==> eat fish
# consume herring ==> eat fish
# consume Clupea harangus ==> eat fish
# consume salmon ==> eat fish
# consume sardine ==> eat fish
# consume sea bass ==> eat fish
# consume shad ==> eat fish
# consume trout ==> eat fish
# consume whitefish ==> eat fish
# consume parr ==> eat fish
# consume whitebait ==> eat fish
# consume striped bass ==> eat fish
# consume striper ==> eat fish
# consume Roccus saxatilis ==> eat fish
# consume rockfish ==> eat fish
# consume allice shad ==> eat fish
# consume allis shad ==> eat fish
# consume allice ==> eat fish
# consume allis ==> eat fish
# consume Alosa alosa ==> eat fish
# consume common American shad ==> eat fish
# consume Alosa sapidissima ==> eat fish
# consume river shad ==> eat fish
# consume Alosa chrysocloris ==> eat fish
# consume brook trout ==> eat fish
# consume speckled trout ==> eat fish
# consume Salvelinus fontinalis ==> eat fish
# consume brown trout ==> eat fish
# consume salmon trout ==> eat fish
# consume Salmo trutta ==> eat fish
# consume lake trout ==> eat fish
# consume Salvelinus namaycush ==> eat fish
# consume rainbow trout ==> eat fish
# consume Salmo gairdneri ==> eat fish
# consume cisco ==> eat fish
# consume lake herring ==> eat fish
# consume Coregonus artedi ==> eat fish
# consume lake whitefish ==> eat fish
# consume Coregonus clupeaformis ==> eat fish
# consume Rocky Mountain whitefish ==> eat fish
# consume Prosopium williamsonii ==> eat fish
# ingest fish ==> eat fish
# ingest aquatic vertebrate ==> eat fish
# ingest vertebrate ==> eat fish
# ingest craniate ==> eat fish
# finish striper ==> eat fish
# finish Roccus saxatilis ==> eat fish
# finish rockfish ==> eat fish
# finish allice shad ==> eat fish
# finish allis shad ==> eat fish
# finish allice ==> eat fish
# finish allis ==> eat fish
# finish Alosa alosa ==> eat fish
# finish common American shad ==> eat fish
# finish Alosa sapidissima ==> eat fish
# finish river shad ==> eat fish
# finish Alosa chrysocloris ==> eat fish
# finish brook trout ==> eat fish
# finish speckled trout ==> eat fish
# finish Salvelinus fontinalis ==> eat fish
# finish brown trout ==> eat fish
# finish salmon trout ==> eat fish
# finish Salmo trutta ==> eat fish
# finish lake trout ==> eat fish
# finish Salvelinus namaycush ==> eat fish
# finish rainbow trout ==> eat fish
# finish Salmo gairdneri ==> eat fish
# finish cisco ==> eat fish
# finish lake herring ==> eat fish
# finish Coregonus artedi ==> eat fish
# finish lake whitefish ==> eat fish
# finish Coregonus clupeaformis ==> eat fish
# finish Rocky Mountain whitefish ==> eat fish
# finish Prosopium williamsonii ==> eat fish
# polish off fish ==> eat fish
# polish off aquatic vertebrate ==> eat fish
# polish off vertebrate ==> eat fish
# polish off craniate ==> eat fish
# polish off chordate ==> eat fish
# polish off animal ==> eat fish
# polish off animate being ==> eat fish
# polish off beast ==> eat fish
# polish off brute ==> eat fish
# polish off creature ==> eat fish
# polish off fauna ==> eat fish
# polish off organism ==> eat fish
# polish off being ==> eat fish
# polish off living thing ==> eat fish
# polish off animate thing ==> eat fish
# polish off bony fish ==> eat fish
# polish off food fish ==> eat fish
# polish off game fish ==> eat fish
# polish off sport fish ==> eat fish
# polish off young fish ==> eat fish
# polish off herring ==> eat fish
# polish off Clupea harangus ==> eat fish
# polish off salmon ==> eat fish
# polish off sardine ==> eat fish
# polish off sea bass ==> eat fish
# polish off shad ==> eat fish
# polish off trout ==> eat fish
# polish off whitefish ==> eat fish
# polish off parr ==> eat fish
# polish off whitebait ==> eat fish
# polish off striped bass ==> eat fish
# polish off striper ==> eat fish
# polish off Roccus saxatilis ==> eat fish
# polish off rockfish ==> eat fish
# polish off allice shad ==> eat fish
# polish off allis shad ==> eat fish
# polish off allice ==> eat fish
# polish off allis ==> eat fish
# polish off Alosa alosa ==> eat fish
# polish off common American shad ==> eat fish
# polish off Alosa sapidissima ==> eat fish
# polish off river shad ==> eat fish
# polish off Alosa chrysocloris ==> eat fish
# polish off brook trout ==> eat fish
# polish off speckled trout ==> eat fish
# polish off Salvelinus fontinalis ==> eat fish
# polish off brown trout ==> eat fish
# polish off salmon trout ==> eat fish
# polish off Salmo trutta ==> eat fish
# polish off lake trout ==> eat fish
# polish off Salvelinus namaycush ==> eat fish
# polish off rainbow trout ==> eat fish
# polish off Salmo gairdneri ==> eat fish
# polish off cisco ==> eat fish
# polish off lake herring ==> eat fish
# polish off Coregonus artedi ==> eat fish
# polish off lake whitefish ==> eat fish
# polish off Coregonus clupeaformis ==> eat fish
# polish off Rocky Mountain whitefish ==> eat fish
# polish off Prosopium williamsonii ==> eat fish
# fare fish ==> eat fish
# fare aquatic vertebrate ==> eat fish
# fare vertebrate ==> eat fish
# fare craniate ==> eat fish
# fare chordate ==> eat fish
# fare animal ==> eat fish
# fare animate being ==> eat fish
# fare beast ==> eat fish
# fare brute ==> eat fish
# fare creature ==> eat fish
# fare fauna ==> eat fish
# fare organism ==> eat fish
# fare being ==> eat fish
# fare living thing ==> eat fish
# fare animate thing ==> eat fish
# fare bony fish ==> eat fish
# fare food fish ==> eat fish
# fare game fish ==> eat fish
# fare sport fish ==> eat fish
# fare young fish ==> eat fish
# fare herring ==> eat fish
# fare Clupea harangus ==> eat fish
# fare salmon ==> eat fish
# fare sardine ==> eat fish
# fare sea bass ==> eat fish
# fare shad ==> eat fish
# fare trout ==> eat fish
# fare whitefish ==> eat fish
# fare parr ==> eat fish
# fare whitebait ==> eat fish
# fare striped bass ==> eat fish
# fare striper ==> eat fish
# fare Roccus saxatilis ==> eat fish
# fare rockfish ==> eat fish
# fare allice shad ==> eat fish
# fare allis shad ==> eat fish
# fare allice ==> eat fish
# fare allis ==> eat fish
# fare Alosa alosa ==> eat fish
# fare common American shad ==> eat fish
# fare Alosa sapidissima ==> eat fish
# fare river shad ==> eat fish
# fare Alosa chrysocloris ==> eat fish
# fare brook trout ==> eat fish
# fare speckled trout ==> eat fish
# fare Salvelinus fontinalis ==> eat fish
# fare brown trout ==> eat fish
# fare salmon trout ==> eat fish
# fare Salmo trutta ==> eat fish
# fare lake trout ==> eat fish
# fare Salvelinus namaycush ==> eat fish
# fare rainbow trout ==> eat fish
# fare Salmo gairdneri ==> eat fish
# fare cisco ==> eat fish
# fare lake herring ==> eat fish
# fare Coregonus artedi ==> eat fish
# fare lake whitefish ==> eat fish
# fare Coregonus clupeaformis ==> eat fish
# fare Rocky Mountain whitefish ==> eat fish
# fare Prosopium williamsonii ==> eat fish
# fill up fish ==> eat fish
# fill up aquatic vertebrate ==> eat fish
# fill up vertebrate ==> eat fish
# fill up craniate ==> eat fish
# fill up chordate ==> eat fish
# fill up animal ==> eat fish
# fill up animate being ==> eat fish
# fill up beast ==> eat fish
# fill up brute ==> eat fish
# fill up creature ==> eat fish
# fill up fauna ==> eat fish
# fill up organism ==> eat fish
# fill up being ==> eat fish
# fill up living thing ==> eat fish
# fill up animate thing ==> eat fish
# fill up bony fish ==> eat fish
# fill up food fish ==> eat fish
# fill up game fish ==> eat fish
# fill up sport fish ==> eat fish
# fill up young fish ==> eat fish
# fill up herring ==> eat fish
# fill up Clupea harangus ==> eat fish
# fill up salmon ==> eat fish
# fill up sardine ==> eat fish
# fill up sea bass ==> eat fish
# fill up shad ==> eat fish
# fill up trout ==> eat fish
# fill up whitefish ==> eat fish
# fill up parr ==> eat fish
# fill up whitebait ==> eat fish
# fill up striped bass ==> eat fish
# fill up striper ==> eat fish
# fill up Roccus saxatilis ==> eat fish
# fill up rockfish ==> eat fish
# fill up allice shad ==> eat fish
# fill up allis shad ==> eat fish
# fill up allice ==> eat fish
# fill up allis ==> eat fish
# fill up Alosa alosa ==> eat fish
# fill up common American shad ==> eat fish
# fill up Alosa sapidissima ==> eat fish
# gluttonise allice ==> eat fish
# ...
# extend animate thing to mythical being ==> give fish to troll
# extend bony fish to troll ==> give fish to troll
# extend bony fish to mythical monster ==> give fish to troll
# extend bony fish to mythical creature ==> give fish to troll
# extend bony fish to monster ==> give fish to troll
# extend bony fish to mythical being ==> give fish to troll
# extend food fish to troll ==> give fish to troll
# extend food fish to mythical monster ==> give fish to troll
# extend food fish to mythical creature ==> give fish to troll
# extend food fish to monster ==> give fish to troll
# extend food fish to mythical being ==> give fish to troll
# extend game fish to troll ==> give fish to troll
# extend game fish to mythical monster ==> give fish to troll
# extend game fish to mythical creature ==> give fish to troll
# extend game fish to monster ==> give fish to troll
# extend game fish to mythical being ==> give fish to troll
# extend sport fish to troll ==> give fish to troll
# extend sport fish to mythical monster ==> give fish to troll
# extend sport fish to mythical creature ==> give fish to troll
# extend sport fish to monster ==> give fish to troll
# extend sport fish to mythical being ==> give fish to troll
# extend young fish to troll ==> give fish to troll
# extend young fish to mythical monster ==> give fish to troll
# extend young fish to mythical creature ==> give fish to troll
# extend young fish to monster ==> give fish to troll
# extend young fish to mythical being ==> give fish to troll
# extend herring to troll ==> give fish to troll
# extend herring to mythical monster ==> give fish to troll
# extend herring to mythical creature ==> give fish to troll
# extend herring to monster ==> give fish to troll
# extend herring to mythical being ==> give fish to troll
# extend Clupea harangus to troll ==> give fish to troll
# extend Clupea harangus to mythical monster ==> give fish to troll
# extend Clupea harangus to mythical creature ==> give fish to troll
# extend Clupea harangus to monster ==> give fish to troll
# extend Clupea harangus to mythical being ==> give fish to troll
# extend salmon to troll ==> give fish to troll
# extend salmon to mythical monster ==> give fish to troll
# extend salmon to mythical creature ==> give fish to troll
# extend salmon to monster ==> give fish to troll
# extend salmon to mythical being ==> give fish to troll
# extend sardine to troll ==> give fish to troll
# extend sardine to mythical monster ==> give fish to troll
# extend sardine to mythical creature ==> give fish to troll
# extend sardine to monster ==> give fish to troll
# extend sardine to mythical being ==> give fish to troll
# extend sea bass to troll ==> give fish to troll
# extend sea bass to mythical monster ==> give fish to troll
# extend sea bass to mythical creature ==> give fish to troll
# extend sea bass to monster ==> give fish to troll
# extend sea bass to mythical being ==> give fish to troll
# extend shad to troll ==> give fish to troll
# extend shad to mythical monster ==> give fish to troll
# extend shad to mythical creature ==> give fish to troll
# extend shad to monster ==> give fish to troll
# extend shad to mythical being ==> give fish to troll
# extend trout to troll ==> give fish to troll
# extend trout to mythical monster ==> give fish to troll
# extend trout to mythical creature ==> give fish to troll
# extend trout to monster ==> give fish to troll
# extend trout to mythical being ==> give fish to troll
# extend whitefish to troll ==> give fish to troll
# extend whitefish to mythical monster ==> give fish to troll
# extend whitefish to mythical creature ==> give fish to troll
# extend whitefish to monster ==> give fish to troll
# extend whitefish to mythical being ==> give fish to troll
# extend parr to troll ==> give fish to troll
# extend parr to mythical monster ==> give fish to troll
# extend parr to mythical creature ==> give fish to troll
# extend parr to monster ==> give fish to troll
# extend parr to mythical being ==> give fish to troll
# extend whitebait to troll ==> give fish to troll
# extend whitebait to mythical monster ==> give fish to troll
# extend whitebait to mythical creature ==> give fish to troll
# extend whitebait to monster ==> give fish to troll
# extend whitebait to mythical being ==> give fish to troll
# extend striped bass to troll ==> give fish to troll
# extend striped bass to mythical monster ==> give fish to troll
# extend striped bass to mythical creature ==> give fish to troll
# extend striped bass to monster ==> give fish to troll
# extend striped bass to mythical being ==> give fish to troll
# extend striper to troll ==> give fish to troll
# extend striper to mythical monster ==> give fish to troll
# extend striper to mythical creature ==> give fish to troll
# extend striper to monster ==> give fish to troll
# extend striper to mythical being ==> give fish to troll
# extend Roccus saxatilis to troll ==> give fish to troll
# extend Roccus saxatilis to mythical monster ==> give fish to troll
# extend Roccus saxatilis to mythical creature ==> give fish to troll
# extend Roccus saxatilis to monster ==> give fish to troll
# extend Roccus saxatilis to mythical being ==> give fish to troll
# extend rockfish to troll ==> give fish to troll
# extend rockfish to mythical monster ==> give fish to troll
# extend rockfish to mythical creature ==> give fish to troll
# extend rockfish to monster ==> give fish to troll
# extend rockfish to mythical being ==> give fish to troll
# extend allice shad to troll ==> give fish to troll
# extend allice shad to mythical monster ==> give fish to troll
# extend allice shad to mythical creature ==> give fish to troll
# extend allice shad to monster ==> give fish to troll
# extend allice shad to mythical being ==> give fish to troll
# extend allis shad to troll ==> give fish to troll
# extend allis shad to mythical monster ==> give fish to troll
# extend allis shad to mythical creature ==> give fish to troll
# extend allis shad to monster ==> give fish to troll
# extend allis shad to mythical being ==> give fish to troll
# extend allice to troll ==> give fish to troll
# extend allice to mythical monster ==> give fish to troll
# extend allice to mythical creature ==> give fish to troll
# extend allice to monster ==> give fish to troll
# extend allice to mythical being ==> give fish to troll
# extend allis to troll ==> give fish to troll
# extend allis to mythical monster ==> give fish to troll
# extend allis to mythical creature ==> give fish to troll
# extend allis to monster ==> give fish to troll
# extend allis to mythical being ==> give fish to troll
# extend Alosa alosa to troll ==> give fish to troll
# extend Alosa alosa to mythical monster ==> give fish to troll
# extend Alosa alosa to mythical creature ==> give fish to troll
# extend Alosa alosa to monster ==> give fish to troll
# extend Alosa alosa to mythical being ==> give fish to troll
# extend common American shad to troll ==> give fish to troll
# extend common American shad to mythical monster ==> give fish to troll
# extend common American shad to mythical creature ==> give fish to troll
# extend common American shad to monster ==> give fish to troll
# extend common American shad to mythical being ==> give fish to troll
# extend Alosa sapidissima to troll ==> give fish to troll
# extend Alosa sapidissima to mythical monster ==> give fish to troll
# extend Alosa sapidissima to mythical creature ==> give fish to troll
# extend Alosa sapidissima to monster ==> give fish to troll
# extend Alosa sapidissima to mythical being ==> give fish to troll
# extend river shad to troll ==> give fish to troll
# extend river shad to mythical monster ==> give fish to troll
# extend river shad to mythical creature ==> give fish to troll
# extend river shad to monster ==> give fish to troll
# extend river shad to mythical being ==> give fish to troll
# extend Alosa chrysocloris to troll ==> give fish to troll
# extend Alosa chrysocloris to mythical monster ==> give fish to troll
# extend Alosa chrysocloris to mythical creature ==> give fish to troll
# extend Alosa chrysocloris to monster ==> give fish to troll
# extend Alosa chrysocloris to mythical being ==> give fish to troll
# extend brook trout to troll ==> give fish to troll
# extend brook trout to mythical monster ==> give fish to troll
# extend brook trout to mythical creature ==> give fish to troll
# extend brook trout to monster ==> give fish to troll
# extend brook trout to mythical being ==> give fish to troll
# extend speckled trout to troll ==> give fish to troll
# extend speckled trout to mythical monster ==> give fish to troll
# extend speckled trout to mythical creature ==> give fish to troll
# extend speckled trout to monster ==> give fish to troll
# extend speckled trout to mythical being ==> give fish to troll
# extend Salvelinus fontinalis to troll ==> give fish to troll
# extend Salvelinus fontinalis to mythical monster ==> give fish to troll
# extend Salvelinus fontinalis to mythical creature ==> give fish to troll
# extend Salvelinus fontinalis to monster ==> give fish to troll
# extend Salvelinus fontinalis to mythical being ==> give fish to troll
# extend brown trout to troll ==> give fish to troll
# extend brown trout to mythical monster ==> give fish to troll
# extend brown trout to mythical creature ==> give fish to troll
# extend brown trout to monster ==> give fish to troll
# extend brown trout to mythical being ==> give fish to troll
# extend salmon trout to troll ==> give fish to troll
# extend salmon trout to mythical monster ==> give fish to troll
# extend salmon trout to mythical creature ==> give fish to troll
# extend salmon trout to monster ==> give fish to troll
# extend salmon trout to mythical being ==> give fish to troll
# extend Salmo trutta to troll ==> give fish to troll
# extend Salmo trutta to mythical monster ==> give fish to troll
# extend Salmo trutta to mythical creature ==> give fish to troll
# extend Salmo trutta to monster ==> give fish to troll
# extend Salmo trutta to mythical being ==> give fish to troll
# extend lake trout to troll ==> give fish to troll
# extend lake trout to mythical monster ==> give fish to troll
# extend lake trout to mythical creature ==> give fish to troll
# extend lake trout to monster ==> give fish to troll
# extend lake trout to mythical being ==> give fish to troll
# extend Salvelinus namaycush to troll ==> give fish to troll
# extend Salvelinus namaycush to mythical monster ==> give fish to troll
# extend Salvelinus namaycush to mythical creature ==> give fish to troll
# extend Salvelinus namaycush to monster ==> give fish to troll
# extend Salvelinus namaycush to mythical being ==> give fish to troll
# extend rainbow trout to troll ==> give fish to troll
# extend rainbow trout to mythical monster ==> give fish to troll
# extend rainbow trout to mythical creature ==> give fish to troll
# extend rainbow trout to monster ==> give fish to troll
# extend rainbow trout to mythical being ==> give fish to troll
# extend Salmo gairdneri to troll ==> give fish to troll
# extend Salmo gairdneri to mythical monster ==> give fish to troll
# extend Salmo gairdneri to mythical creature ==> give fish to troll
# extend Salmo gairdneri to monster ==> give fish to troll
# extend Salmo gairdneri to mythical being ==> give fish to troll
# extend cisco to troll ==> give fish to troll
# extend cisco to mythical monster ==> give fish to troll
# extend cisco to mythical creature ==> give fish to troll
# extend cisco to monster ==> give fish to troll
# extend cisco to mythical being ==> give fish to troll
# extend lake herring to troll ==> give fish to troll
# extend lake herring to mythical monster ==> give fish to troll
# extend lake herring to mythical creature ==> give fish to troll
# extend lake herring to monster ==> give fish to troll
# extend lake herring to mythical being ==> give fish to troll
# extend Coregonus artedi to troll ==> give fish to troll
# extend Coregonus artedi to mythical monster ==> give fish to troll
# extend Coregonus artedi to mythical creature ==> give fish to troll
# extend Coregonus artedi to monster ==> give fish to troll
# extend Coregonus artedi to mythical being ==> give fish to troll
# extend lake whitefish to troll ==> give fish to troll
# extend lake whitefish to mythical monster ==> give fish to troll
# extend lake whitefish to mythical creature ==> give fish to troll
# extend lake whitefish to monster ==> give fish to troll
# extend lake whitefish to mythical being ==> give fish to troll
# extend Coregonus clupeaformis to troll ==> give fish to troll
# extend Coregonus clupeaformis to mythical monster ==> give fish to troll
# extend Coregonus clupeaformis to mythical creature ==> give fish to troll
# extend Coregonus clupeaformis to monster ==> give fish to troll
# extend Coregonus clupeaformis to mythical being ==> give fish to troll
# extend Rocky Mountain whitefish to troll ==> give fish to troll
# extend Rocky Mountain whitefish to mythical monster ==> give fish to troll
# extend Rocky Mountain whitefish to mythical creature ==> give fish to troll
# extend Rocky Mountain whitefish to monster ==> give fish to troll
# extend Rocky Mountain whitefish to mythical being ==> give fish to troll
# extend Prosopium williamsonii to troll ==> give fish to troll
# extend Prosopium williamsonii to mythical monster ==> give fish to troll
# extend Prosopium williamsonii to mythical creature ==> give fish to troll
# extend Prosopium williamsonii to monster ==> give fish to troll
# extend Prosopium williamsonii to mythical being ==> give fish to troll
# propose to the princess ==> propose to the princess
# propose to the aristocrat ==> propose to the princess
# propose to the blue blood ==> propose to the princess
# propose to the patrician ==> propose to the princess
# propose to the crown princess ==> propose to the princess
# propose to the maharani ==> propose to the princess
# propose to the maharanee ==> propose to the princess
# declare oneself to the princess ==> propose to the princess
# declare oneself to the aristocrat ==> propose to the princess
# declare oneself to the blue blood ==> propose to the princess
# declare oneself to the patrician ==> propose to the princess
# declare oneself to the crown princess ==> propose to the princess
# declare oneself to the maharani ==> propose to the princess
# declare oneself to the maharanee ==> propose to the princess
# offer to the princess ==> propose to the princess
# offer to the aristocrat ==> propose to the princess
# offer to the blue blood ==> propose to the princess
# offer to the patrician ==> propose to the princess
# offer to the crown princess ==> propose to the princess
# offer to the maharani ==> propose to the princess
# offer to the maharanee ==> propose to the princess
# pop the question to the princess ==> propose to the princess
# pop the question to the aristocrat ==> propose to the princess
# pop the question to the blue blood ==> propose to the princess
# pop the question to the patrician ==> propose to the princess
# pop the question to the crown princess ==> propose to the princess
# pop the question to the maharani ==> propose to the princess
# pop the question to the maharanee ==> propose to the princess
# request to the princess ==> propose to the princess
# request to the aristocrat ==> propose to the princess
# request to the blue blood ==> propose to the princess
# request to the patrician ==> propose to the princess
# request to the crown princess ==> propose to the princess
# request to the maharani ==> propose to the princess
# request to the maharanee ==> propose to the princess
# ask to the princess ==> propose to the princess
# ask to the aristocrat ==> propose to the princess
# ask to the blue blood ==> propose to the princess
# ask to the patrician ==> propose to the princess
# ask to the crown princess ==> propose to the princess
# ask to the maharani ==> propose to the princess
# ask to the maharanee ==> propose to the princess
# go north ==> go north
# go northerly ==> go north
# go northwards ==> go north
# go northward ==> go north
# go away north ==> go north
# go away northerly ==> go north
# go away northwards ==> go north
# go away northward ==> go north
# depart north ==> go north
# depart northerly ==> go north
# depart northwards ==> go north
# depart northward ==> go north
# Congratulations you can now handle 12524 commands instead of just 7!
